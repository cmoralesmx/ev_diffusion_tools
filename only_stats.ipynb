# %%
import bz2
import numpy as np
import pandas as pd
import pickle
import scipy.stats as sp_stats
from itertools import product

sections = ['utj', 'isthmus', 'ia-junction', 'ampulla1', 'ampulla2']

classes2 = {'ordering':[('narrow_end','#30a2da'), ('wide_end','#fc4f30'), ('narrow_lumen','#e5ae38'),('wide_lumen','green')]}
classes2['utj'] = {'narrow_end':[1,2,3, 7,8, 13,21], 'wide_end':[4,5,6, 9,14,19], 'narrow_lumen':[15, 16, 17,18], 'wide_lumen':[10,11,12, 20]}
classes2['isthmus'] = {'narrow_end':[1,2,3,4,5,6], 'wide_end':[7,8, 9], 'narrow_lumen':[10, 11, 12, 13, 14, 15], 'wide_lumen':[16,17,18,19,20,21]}
classes2['ia-junction'] = {'narrow_end':[1,2,3,4,5,6,7,8], 'wide_end':[9,10,11,12,13,14,15,16], 'narrow_lumen':[17,18,19,20,21,22,23,24], 'wide_lumen':[25,26,27,28,29,30,31,32]}
classes2['ampulla1'] = {'narrow_end':[1,2,3,4,5,6], 'wide_end':[7,8,9,10, 11, 12], 'narrow_lumen':[13,14,15,16,17,18], 'wide_lumen':[19, 20, 21, 22, 23, 24]}
classes2['ampulla2'] = {'narrow_end':[1,2,3,4,5,6], 'wide_end':[7,8,9,10, 11, 12], 'narrow_lumen':[13,14,15,16,17,18], 'wide_lumen':[19, 20, 21, 22, 23, 24]}

# load the stats for the experiment
with bz2.BZ2File('./resources/analysis/output/cross_section_stats_v2d2_isth_amp.pickle.bz2', 'rb') as stats_file:
    stats_v2b = pickle.load(stats_file)
print(stats_v2b.keys())

v2b_data = None
for sec in sections:
    if sec in stats_v2b and 'data_frame' in stats_v2b[sec]:
        if v2b_data is None:
            v2b_data = stats_v2b[sec]['data_frame']
        else:
            v2b_data = v2b_data.append(stats_v2b[sec]['data_frame'])

print('EVs in replicate 1 in Ampulla',v2b_data.query("section=='ampulla1' & replicate==1")['radius_um'].count())
print('EVs in replicate 1 in Isthmus',v2b_data.query("section=='isthmus' & replicate==1")['radius_um'].count())
# Out:
# dict_keys(['isthmus', 'ampulla1'])
# EVs in replicate 1 in Ampulla 194
# EVs in replicate 1 in Isthmus 1025

# %% [markdown]
# |Aims| Parametric | Non-parametric |
# |-|-|-|
# |Compare samples from 2 independent data sets|2 sample T-Test (Student's)|Mann-Whitney U|
# |Compare samples from 2 paired data sets|paired Student T-test|Wilcoxon Signed-Rank|
# |Compare samples from >2 indep. data sets|one-way ANOVA|Kruskal-Wallis H Test|
# |Compare samples from >2 paired data sets|repeated measures ANOVA|Friedman|
#
# ## Statistics functions follow

# %%
"""
Kolmogorov-Smirnov (one of the most common methods?)
exact with continuous distributions, less precise with discrete distributions
ks_stat, ks_p = sp_stats.ks_2samp(d1, d2)

Mann Withney U test, needs n > 25
robust to violations of homogeneity of variance

Ranksums similar to mw, assumes continuous distributions. It does not handle ties between measurements in x and y, (MW does)
rank_stat, rank_p = sp_stats.ranksums(d1, d2)

Epps-Singleton does not assume a continuous distribution, needs n > 25

brunnermunzel does not test if both distributions are the same
"""

def test_significance_non_parametric(d1, n_d1, d2, n_d2, alpha=0.05, continuous_distribution=True, paired_samples=False):
    """
    Useful tests for paired and non-paired non-parametric samples.
    """
    if n_d1 < 25 or n_d2 < 25:
        print('n<25, using the Anderson-Darling test for k-samples,', end =' ')
        # returns statistc, critical values, and significance level
        ak_stat, ak_critical_values, ak_significance_level = sp_stats.anderson_ksamp([d1, d2])
        # is the test value greater than the critical value for 5%?
        if ak_stat > ak_critical_values[2]:
            print(f'significance level: {ak_significance_level:.4f}, Reject H0')
            return True, ak_significance_level
    else:
        p_normal1 = test_normality(d1)
        p_normal2 = test_normality(d2)
        
        if n_d1 > 100 and n_d2 > 100:
            print('N is sufficiently large, parametric test will take precedence')
            return test_significance_parametric(d1, n_d1, d2, n_d2, alpha, paired_samples)
        else:
            if continuous_distribution:
                if paired_samples:
                    # wilcoxon signed-rank
                    wsr_stat, wsr_p = sp_stats.wilcoxon(d1, d2)
                    print('| Wilcoxon signed-rank,', end=' ')
                    if wsr_p > alpha:
                        pass
                    else:
                        print(f'stat:{wsr_stat} p: {wsr_p:.4f}, Reject H0')
                        return True, mwu_p
                else:
                    # Mann-Whitney U
                    mwu_stat, mwu_p = sp_stats.mannwhitneyu(d1, d2)
                    print('| Mann-Whitney U,', end=' ')
                    if mwu_p > alpha:
                        pass
                    else:
                        print(f'stat:{mwu_stat} p: {mwu_p:.4f}, Reject H0')
                        return True, mwu_p
            else:
                epps_stat, epps_p = sp_stats.epps_singleton_2samp(d1, d2)
                print('| Epps singleton 2 samp,', end=' ')
                if epps_p > alpha:
                    pass # print(f'Fail to reject h0')
                else:
                    print(f'p:{epps_p:.4f}, Reject H0')
                    return True, epps_p
    
    print('N.S.')
    return False, None

def test_normality(data):
    """
    Only the result from D'Agostino and Pearson's test is reported
    """
    statistic, p = sp_stats.normaltest(data)
    
    print(f'normality test', f'p={p:.3f}' if p > 1E-3 else f'p={p:.3E}', end=' ')
    if p < 0.05:
        print('(sig. non-normal)', end=' ')
    return p

def test_variance_homogeneity(d1, d2, p_normal1, p_normal2):
    """
    Levene test is more robust for data with significant deviations from normality
    """
    if p_normal1 > 0.05 and p_normal2 > 0.05:
        bartlet_stat, p_var = sp_stats.bartlett(d1, d2)
        print('variance homogeneity test (bartlett)', f'p={p_var:.3E}' if p_var < 1E-3 else f'p={p_var:.3f}', end=' ')
    else:
        levene_stat, p_var = sp_stats.levene(d1, d2)
        print(f'variance homogeneity test (levene)', f'p={p_var:.3E}' if p_var < 1E-3 else f'p={p_var:.3f}', end=' ')
    return p_var

def test_significance_parametric(d1, n_d1, d2, n_d2, alpa=0.05, paired_samples=False, p_normal1=None, p_normal2=None):
    """
    Useful tests for paired and non-paired non-parametric samples.
    These tests assume coninuous distributions
    """
    if n_d1 < 100 and n_d2 < 100:
        if n_d1 < 20 or n_d2 < 20:
            print('WARNING Sample size is too-low, non-parametric test must be used instead.')
            return False, None
        else:
            print('Sample size is low 20 < n < 100')
    if p_normal1 is None:
        p_normal1 = test_normality(d1)
    if p_normal2 is None:
        p_normal2 = test_normality(d2)
    # test equal variances
    p_var = test_variance_homogeneity(d1, d2, p_normal1, p_normal2)

    if paired_samples:
        # paired samples t-test
        ttest_stat, ttest_p = sp_stats.ttest_rel(d1, d2)
        print('| t-test paired,', end=' ')
    else:
        # independent samples t-test, assumes identical variances
        # We need to set equal_var=False if samples have different sizes https://stackoverflow.com/a/22613361 to execute a welch's test
        ttest_stat, ttest_p = sp_stats.ttest_ind(d1, d2, equal_var=False if p_var > alpha and n_d1 != n_d2 else p_var > alpha)
        print('| t-test indep.,', end=' ')
        
    if ttest_p > alpha:
        print('N.S.')
        return False, None
    else:
        print(f'p={ttest_p:.4f}, Reject H0')
        return True, ttest_p

# %%
def most_repeating_significant_differences(significant_differences):
    # identify the most repeating significant differences
    reps = dict()
    for r in range(len(significant_differences)):
        #print('In repeat',r)
        for d in significant_differences[r]:
            s = tuple(d[:2])
            if s not in reps:
                reps[s] = []
            reps[s].append([r,d[2]])

    # rank the identified repeating pairs by their frequency they repeat
    sorted_by_repeats = {}
    for k, repeats in reversed(sorted(reps.items(), key=lambda t: len(t[1]))):
        if len(repeats) not in sorted_by_repeats:
            sorted_by_repeats[len(repeats)] = []
        sorted_by_repeats[len(repeats)].append((k, repeats))

    # display those significant in every repeat
    print('Significantly different pairs of ROI in more than one repeat:')
    for k,pairs in sorted_by_repeats.items():
        if k > 1:
            print('repeats:', k)
            for pair in pairs:
                print(pair[0], end=' ')
                for values in pair[1]:
                    print(f'rep:{values[0]}', f'p={values[1]:.4f},' if values[1] > 0.0001 else f'{values[1]:.2E},', end=' ')
                print()

# %%
def differences_between_same_class_rois_in_same_cross_section(section, alpha):
    print('H0: both samples were drawn from a population with the same distribution')
    # we reject h0 if there is evidence to suggest the samples were taken from two differt distributions
    counters = {'tested':0, 'skipped':0}
    
    significant_differences = []
    # identify those pairs with significant differences
    for rep in range(5):
        differences = []
        for k,colour in classes2['ordering']:
            print('class:', k, 'replicate:', rep)
            print(section, k)
            # compute the combinations of same class elements
            for roi_1, roi_2 in combinations(classes2[s1][k], 2):
                d1 = v2b_data.query(f"section=='{section}' & replicate=={rep} & roi=={roi_1-1}")['radius_um']
                d2 = v2b_data.query(f"section=='{section}' & replicate=={rep} & roi=={roi_2-1}")['radius_um']
                n_d1, n_d2 = len(d1), len(d2)

                print(f'roi {roi_1} ({n_d1}) - roi {roi_2} ({n_d2})', end=' ')
                if n_d1 < 2 or n_d2 < 2:
                    print('SKIPPING pair due to scarcity of observations')
                    counters['skipped'] += 1
                else:
                    significant, significance = test_significance_non_parametric(d1, n_d1, d2, n_d2, alpha, continuous_distribution=True, paired_samples=False)
                    counters['tested'] += 1
                    if significant:
                        differences.append([roi_1, roi_2, significance])
        significant_differences.append(differences)
    ts = len([e for l in significant_differences for e in l])
    print('Pairs tested:', counters['tested'], 'skipped:', counters['skipped'], 'significant:', ts, 'total:', counters['tested'] + counters['skipped'] + ts)
    return significant_differences

# %%
# I need to compare based on the pooled variance per class
def differences_between_non_same_class_rois_in_same_cross_section(section, alpha):
    print('H0: both samples were drawn from a population with the same distribution')
    # we reject h0 if there is evidence to suggest the samples were taken from two differt distributions
    counters = {'tested':0, 'skipped':0}
    
    significant_differences = []
    # identify those pairs with significant differences
    for rep in range(5):
        differences = []
        for k,colour in classes2['ordering']:
            print('class:', k, 'replicate:', rep)
            print(section, k)
            # compute the combinations of same class elements
            for roi_1, roi_2 in combinations(classes2[s1][k], 2):
                d1 = v2b_data.query(f"section=='{section}' & replicate=={rep} & roi=={roi_1-1}")['radius_um']
                d2 = v2b_data.query(f"section=='{section}' & replicate=={rep} & roi=={roi_2-1}")['radius_um']
                n_d1, n_d2 = len(d1), len(d2)

                print(f'roi {roi_1} ({n_d1}) - roi {roi_2} ({n_d2})', end=' ')
                if n_d1 < 2 or n_d2 < 2:
                    print('SKIPPING pair due to scarcity of observations')
                    counters['skipped'] += 1
                else:
                    significant, significance = test_significance_non_parametric(d1, n_d1, d2, n_d2, alpha, continuous_distribution=True, paired_samples=False)
                    counters['tested'] += 1
                    if significant:
                        differences.append([roi_1, roi_2, significance])
        significant_differences.append(differences)
    ts = len([e for l in significant_differences for e in l])
    print('Pairs tested:', counters['tested'], 'skipped:', counters['skipped'], 'significant:', ts, 'total:', counters['tested'] + counters['skipped'] + ts)
    return significant_differences

# %%
len([e for l in significant_differences for e in l])
# Out:
# 16

# %%
# Differences between ROIs of the same class Isthmus
significant_differences = differences_between_same_class_rois_in_same_cross_section('isthmus', 0.05)
# Out:
# H0: both samples were drawn from a population with the same distribution
# class: narrow_end replicate: 0
# isthmus narrow_end
# roi 1 (66) - roi 2 (72) normality test p=0.009 (sig. non-normal) normality test p=4.137E-07 (sig. non-normal) | Mann-Withney U, N.S.
# roi 1 (66) - roi 3 (114) normality test p=0.009 (sig. non-normal) normality test p=1.523E-11 (sig. non-normal) | Mann-Withney U, N.S.
# roi 1 (66) - roi 4 (70) normality test p=0.009 (sig. non-normal) normality test p=4.235E-04 (sig. non-normal) | Mann-Withney U, N.S.
# roi 1 (66) - roi 5 (82) normality test p=0.009 (sig. non-normal) normality test p=6.738E-08 (sig. non-normal) | Mann-Withney U, N.S.
# roi 1 (66) - roi 6 (61) normality test p=0.009 (sig. non-normal) normality test p=0.650 | Mann-Withney U, N.S.
# roi 2 (72) - roi 3 (114) normality test p=4.137E-07 (sig. non-normal) normality test p=1.523E-11 (sig. non-normal) | Mann-Withney U, N.S.
# roi 2 (72) - roi 4 (70) normality test p=4.137E-07 (sig. non-normal) normality test p=4.235E-04 (sig. non-normal) | Mann-Withney U, N.S.
# roi 2 (72) - roi 5 (82) normality test p=4.137E-07 (sig. non-normal) normality test p=6.738E-08 (sig. non-normal) | Mann-Withney U, N.S.
# roi 2 (72) - roi 6 (61) normality test p=4.137E-07 (sig. non-normal) normality test p=0.650 | Mann-Withney U, N.S.
# roi 3 (114) - roi 4 (70) normality test p=1.523E-11 (sig. non-normal) normality test p=4.235E-04 (sig. non-normal) | Mann-Withney U, N.S.
# roi 3 (114) - roi 5 (82) normality test p=1.523E-11 (sig. non-normal) normality test p=6.738E-08 (sig. non-normal) | Mann-Withney U, N.S.
# roi 3 (114) - roi 6 (61) normality test p=1.523E-11 (sig. non-normal) normality test p=0.650 | Mann-Withney U, N.S.
# roi 4 (70) - roi 5 (82) normality test p=4.235E-04 (sig. non-normal) normality test p=6.738E-08 (sig. non-normal) | Mann-Withney U, N.S.
# roi 4 (70) - roi 6 (61) normality test p=4.235E-04 (sig. non-normal) normality test p=0.650 | Mann-Withney U, N.S.
# roi 5 (82) - roi 6 (61) normality test p=6.738E-08 (sig. non-normal) normality test p=0.650 | Mann-Withney U, N.S.
# class: wide_end replicate: 0
# isthmus wide_end
# roi 7 (33) - roi 8 (80) normality test p=0.030 (sig. non-normal) normality test p=0.002 (sig. non-normal) | Mann-Withney U, N.S.
# roi 7 (33) - roi 9 (45) normality test p=0.030 (sig. non-normal) normality test p=0.007 (sig. non-normal) | Mann-Withney U, N.S.
# roi 7 (33) - roi 10 (52) normality test p=0.030 (sig. non-normal) normality test p=2.590E-10 (sig. non-normal) | Mann-Withney U, N.S.
# roi 7 (33) - roi 11 (32) normality test p=0.030 (sig. non-normal) normality test p=0.009 (sig. non-normal) | Mann-Withney U, N.S.
# roi 7 (33) - roi 12 (63) normality test p=0.030 (sig. non-normal) normality test p=1.326E-08 (sig. non-normal) | Mann-Withney U, N.S.
# roi 8 (80) - roi 9 (45) normality test p=0.002 (sig. non-normal) normality test p=0.007 (sig. non-normal) | Mann-Withney U, N.S.
# roi 8 (80) - roi 10 (52) normality test p=0.002 (sig. non-normal) normality test p=2.590E-10 (sig. non-normal) | Mann-Withney U, N.S.
# roi 8 (80) - roi 11 (32) normality test p=0.002 (sig. non-normal) normality test p=0.009 (sig. non-normal) | Mann-Withney U, N.S.
# roi 8 (80) - roi 12 (63) normality test p=0.002 (sig. non-normal) normality test p=1.326E-08 (sig. non-normal) | Mann-Withney U, N.S.
# roi 9 (45) - roi 10 (52) normality test p=0.007 (sig. non-normal) normality test p=2.590E-10 (sig. non-normal) | Mann-Withney U, N.S.
# roi 9 (45) - roi 11 (32) normality test p=0.007 (sig. non-normal) normality test p=0.009 (sig. non-normal) | Mann-Withney U, N.S.
# roi 9 (45) - roi 12 (63) normality test p=0.007 (sig. non-normal) normality test p=1.326E-08 (sig. non-normal) | Mann-Withney U, N.S.
# roi 10 (52) - roi 11 (32) normality test p=2.590E-10 (sig. non-normal) normality test p=0.009 (sig. non-normal) | Mann-Withney U, N.S.
# roi 10 (52) - roi 12 (63) normality test p=2.590E-10 (sig. non-normal) normality test p=1.326E-08 (sig. non-normal) | Mann-Withney U, N.S.
# roi 11 (32) - roi 12 (63) normality test p=0.009 (sig. non-normal) normality test p=1.326E-08 (sig. non-normal) | Mann-Withney U, N.S.
# class: narrow_lumen replicate: 0
# isthmus narrow_lumen
# roi 13 (46) - roi 14 (29) normality test p=0.002 (sig. non-normal) normality test p=0.006 (sig. non-normal) | Mann-Withney U, N.S.
# roi 13 (46) - roi 15 (67) normality test p=0.002 (sig. non-normal) normality test p=0.001 (sig. non-normal) | Mann-Withney U, N.S.
# roi 13 (46) - roi 16 (21) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 13 (46) - roi 17 (19) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 13 (46) - roi 18 (10) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 14 (29) - roi 15 (67) normality test p=0.006 (sig. non-normal) normality test p=0.001 (sig. non-normal) | Mann-Withney U, N.S.
# roi 14 (29) - roi 16 (21) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 14 (29) - roi 17 (19) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 14 (29) - roi 18 (10) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 15 (67) - roi 16 (21) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 15 (67) - roi 17 (19) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 15 (67) - roi 18 (10) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 16 (21) - roi 17 (19) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 16 (21) - roi 18 (10) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 17 (19) - roi 18 (10) n<25, using the Anderson-Darling test for k-samples, N.S.
# class: wide_lumen replicate: 0
# isthmus wide_lumen
# roi 19 (11) - roi 20 (13) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 19 (11) - roi 21 (14) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 19 (11) - roi 22 (0) SKIPPING pair due to scarcity of observations
# roi 19 (11) - roi 23 (0)
# C:\Users\carlos2\Miniconda3\envs\data_analysis_py36\lib\site-packages\ipykernel_launcher.py:24: UserWarning: p-value capped: true value larger than 0.25
#  SKIPPING pair due to scarcity of observations
# roi 19 (11) - roi 24 (0) SKIPPING pair due to scarcity of observations
# roi 20 (13) - roi 21 (14) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 20 (13) - roi 22 (0) SKIPPING pair due to scarcity of observations
# roi 20 (13) - roi 23 (0) SKIPPING pair due to scarcity of observations
# roi 20 (13) - roi 24 (0) SKIPPING pair due to scarcity of observations
# roi 21 (14) - roi 22 (0) SKIPPING pair due to scarcity of observations
# roi 21 (14) - roi 23 (0) SKIPPING pair due to scarcity of observations
# roi 21 (14) - roi 24 (0) SKIPPING pair due to scarcity of observations
# roi 22 (0) - roi 23 (0) SKIPPING pair due to scarcity of observations
# roi 22 (0) - roi 24 (0) SKIPPING pair due to scarcity of observations
# roi 23 (0) - roi 24 (0) SKIPPING pair due to scarcity of observations
# class: narrow_end replicate: 1
# isthmus narrow_end
# roi 1 (66) - roi 2 (68) normality test p=2.766E-07 (sig. non-normal) normality test p=1.118E-06 (sig. non-normal) | Mann-Withney U, N.S.
# roi 1 (66) - roi 3 (124) normality test p=2.766E-07 (sig. non-normal) normality test p=3.775E-09 (sig. non-normal) | Mann-Withney U, N.S.
# roi 1 (66) - roi 4 (67) normality test p=2.766E-07 (sig. non-normal) normality test p=1.232E-04 (sig. non-normal) | Mann-Withney U, N.S.
# roi 1 (66) - roi 5 (83) normality test p=2.766E-07 (sig. non-normal) normality test p=0.004 (sig. non-normal) | Mann-Withney U, N.S.
# roi 1 (66) - roi 6 (80) normality test p=2.766E-07 (sig. non-normal) normality test p=5.666E-04 (sig. non-normal) | Mann-Withney U, N.S.
# roi 2 (68) - roi 3 (124) normality test p=1.118E-06 (sig. non-normal) normality test p=3.775E-09 (sig. non-normal) | Mann-Withney U, N.S.
# roi 2 (68) - roi 4 (67) normality test p=1.118E-06 (sig. non-normal) normality test p=1.232E-04 (sig. non-normal) | Mann-Withney U, N.S.
# roi 2 (68) - roi 5 (83) normality test p=1.118E-06 (sig. non-normal) normality test p=0.004 (sig. non-normal) | Mann-Withney U, N.S.
# roi 2 (68) - roi 6 (80) normality test p=1.118E-06 (sig. non-normal) normality test p=5.666E-04 (sig. non-normal) | Mann-Withney U, N.S.
# roi 3 (124) - roi 4 (67) normality test p=3.775E-09 (sig. non-normal) normality test p=1.232E-04 (sig. non-normal) | Mann-Withney U, N.S.
# roi 3 (124) - roi 5 (83) normality test p=3.775E-09 (sig. non-normal) normality test p=0.004 (sig. non-normal) | Mann-Withney U, N.S.
# roi 3 (124) - roi 6 (80) normality test p=3.775E-09 (sig. non-normal) normality test p=5.666E-04 (sig. non-normal) | Mann-Withney U, N.S.
# roi 4 (67) - roi 5 (83) normality test p=1.232E-04 (sig. non-normal) normality test p=0.004 (sig. non-normal) | Mann-Withney U, N.S.
# roi 4 (67) - roi 6 (80) normality test p=1.232E-04 (sig. non-normal) normality test p=5.666E-04 (sig. non-normal) | Mann-Withney U, N.S.
# roi 5 (83) - roi 6 (80) normality test p=0.004 (sig. non-normal) normality test p=5.666E-04 (sig. non-normal) | Mann-Withney U, N.S.
# class: wide_end replicate: 1
# isthmus wide_end
# roi 7 (34) - roi 8 (82) normality test p=0.322 normality test p=4.908E-05 (sig. non-normal) | Mann-Withney U, stat:1044.5 p: 0.0171, Reject H0
# roi 7 (34) - roi 9 (42) normality test p=0.322 normality test p=0.320 | Mann-Withney U, N.S.
# roi 7 (34) - roi 10 (42) normality test p=0.322 normality test p=0.009 (sig. non-normal) | Mann-Withney U, stat:545.5 p: 0.0396, Reject H0
# roi 7 (34) - roi 11 (21) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 7 (34) - roi 12 (68) normality test p=0.322 normality test p=1.994E-05 (sig. non-normal) | Mann-Withney U, N.S.
# roi 8 (82) - roi 9 (42) normality test p=4.908E-05 (sig. non-normal) normality test p=0.320 | Mann-Withney U, N.S.
# roi 8 (82) - roi 10 (42) normality test p=4.908E-05 (sig. non-normal) normality test p=0.009 (sig. non-normal) | Mann-Withney U, N.S.
# roi 8 (82) - roi 11 (21) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 8 (82) - roi 12 (68) normality test p=4.908E-05 (sig. non-normal) normality test p=1.994E-05 (sig. non-normal) | Mann-Withney U, N.S.
# roi 9 (42) - roi 10 (42) normality test p=0.320 normality test p=0.009 (sig. non-normal) | Mann-Withney U, N.S.
# roi 9 (42) - roi 11 (21) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 9 (42) - roi 12 (68) normality test p=0.320 normality test p=1.994E-05 (sig. non-normal) | Mann-Withney U, N.S.
# roi 10 (42) - roi 11 (21) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 10 (42) - roi 12 (68) normality test p=0.009 (sig. non-normal) normality test p=1.994E-05 (sig. non-normal) | Mann-Withney U, N.S.
# roi 11 (21) - roi 12 (68) n<25, using the Anderson-Darling test for k-samples, N.S.
# class: narrow_lumen replicate: 1
# isthmus narrow_lumen
# roi 13 (54) - roi 14 (28) normality test p=0.072 normality test p=0.258 | Mann-Withney U, N.S.
# roi 13 (54) - roi 15 (65) normality test p=0.072 normality test p=0.008 (sig. non-normal) | Mann-Withney U, stat:1406.5 p: 0.0316, Reject H0
# roi 13 (54) - roi 16 (27) normality test p=0.072 normality test p=0.124 | Mann-Withney U, stat:563.0 p: 0.0486, Reject H0
# roi 13 (54) - roi 17 (18) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 13 (54) - roi 18 (22) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 14 (28) - roi 15 (65) normality test p=0.258 normality test p=0.008 (sig. non-normal) | Mann-Withney U, N.S.
# roi 14 (28) - roi 16 (27) normality test p=0.258 normality test p=0.124 | Mann-Withney U, N.S.
# roi 14 (28) - roi 17 (18) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 14 (28) - roi 18 (22) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 15 (65) - roi 16 (27) normality test p=0.008 (sig. non-normal) normality test p=0.124 | Mann-Withney U, N.S.
# roi 15 (65) - roi 17 (18) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 15 (65) - roi 18 (22) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 16 (27) - roi 17 (18) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 16 (27) - roi 18 (22) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 17 (18) - roi 18 (22) n<25, using the Anderson-Darling test for k-samples, N.S.
# class: wide_lumen replicate: 1
# isthmus wide_lumen
# roi 19 (10) - roi 20 (12) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 19 (10) - roi 21 (12) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 19 (10) - roi 22 (0) SKIPPING pair due to scarcity of observations
# roi 19 (10) - roi 23 (0) SKIPPING pair due to scarcity of observations
# roi 19 (10) - roi 24 (0) SKIPPING pair due to scarcity of observations
# roi 20 (12) - roi 21 (12) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 20 (12) - roi 22 (0) SKIPPING pair due to scarcity of observations
# roi 20 (12) - roi 23 (0) SKIPPING pair due to scarcity of observations
# roi 20 (12) - roi 24 (0) SKIPPING pair due to scarcity of observations
# roi 21 (12) - roi 22 (0) SKIPPING pair due to scarcity of observations
# roi 21 (12) - roi 23 (0) SKIPPING pair due to scarcity of observations
# roi 21 (12) - roi 24 (0) SKIPPING pair due to scarcity of observations
# roi 22 (0) - roi 23 (0) SKIPPING pair due to scarcity of observations
# roi 22 (0) - roi 24 (0) SKIPPING pair due to scarcity of observations
# roi 23 (0) - roi 24 (0) SKIPPING pair due to scarcity of observations
# class: narrow_end replicate: 2
# isthmus narrow_end
# roi 1 (62) - roi 2 (64) normality test p=2.768E-10 (sig. non-normal) normality test p=1.590E-04 (sig. non-normal) | Mann-Withney U, N.S.
# roi 1 (62) - roi 3 (111) normality test p=2.768E-10 (sig. non-normal) normality test p=2.430E-05 (sig. non-normal) | Mann-Withney U, N.S.
# roi 1 (62) - roi 4 (71) normality test p=2.768E-10 (sig. non-normal) normality test p=3.021E-05 (sig. non-normal) | Mann-Withney U, N.S.
# roi 1 (62) - roi 5 (83) normality test p=2.768E-10 (sig. non-normal) normality test p=1.284E-07 (sig. non-normal) | Mann-Withney U, N.S.
# roi 1 (62) - roi 6 (68) normality test p=2.768E-10 (sig. non-normal) normality test p=0.005 (sig. non-normal) | Mann-Withney U, N.S.
# roi 2 (64) - roi 3 (111) normality test p=1.590E-04 (sig. non-normal) normality test p=2.430E-05 (sig. non-normal) | Mann-Withney U, N.S.
# roi 2 (64) - roi 4 (71) normality test p=1.590E-04 (sig. non-normal) normality test p=3.021E-05 (sig. non-normal) | Mann-Withney U, N.S.
# roi 2 (64) - roi 5 (83) normality test p=1.590E-04 (sig. non-normal) normality test p=1.284E-07 (sig. non-normal) | Mann-Withney U, N.S.
# roi 2 (64) - roi 6 (68) normality test p=1.590E-04 (sig. non-normal) normality test p=0.005 (sig. non-normal) | Mann-Withney U, N.S.
# roi 3 (111) - roi 4 (71) normality test p=2.430E-05 (sig. non-normal) normality test p=3.021E-05 (sig. non-normal) | Mann-Withney U, N.S.
# roi 3 (111) - roi 5 (83) normality test p=2.430E-05 (sig. non-normal) normality test p=1.284E-07 (sig. non-normal) | Mann-Withney U, N.S.
# roi 3 (111) - roi 6 (68) normality test p=2.430E-05 (sig. non-normal) normality test p=0.005 (sig. non-normal) | Mann-Withney U, N.S.
# roi 4 (71) - roi 5 (83) normality test p=3.021E-05 (sig. non-normal) normality test p=1.284E-07 (sig. non-normal) | Mann-Withney U, N.S.
# roi 4 (71) - roi 6 (68) normality test p=3.021E-05 (sig. non-normal) normality test p=0.005 (sig. non-normal) | Mann-Withney U, N.S.
# roi 5 (83) - roi 6 (68) normality test p=1.284E-07 (sig. non-normal) normality test p=0.005 (sig. non-normal) | Mann-Withney U, N.S.
# class: wide_end replicate: 2
# isthmus wide_end
# roi 7 (30) - roi 8 (73) normality test p=0.009 (sig. non-normal) normality test p=6.656E-05 (sig. non-normal) | Mann-Withney U, N.S.
# roi 7 (30) - roi 9 (48) normality test p=0.009 (sig. non-normal) normality test p=0.009 (sig. non-normal) | Mann-Withney U, N.S.
# roi 7 (30) - roi 10 (38) normality test p=0.009 (sig. non-normal) normality test p=0.003 (sig. non-normal) | Mann-Withney U, N.S.
# roi 7 (30) - roi 11 (35) normality test p=0.009 (sig. non-normal) normality test p=6.215E-05 (sig. non-normal) | Mann-Withney U, N.S.
# roi 7 (30) - roi 12 (68) normality test p=0.009 (sig. non-normal) normality test p=4.604E-09 (sig. non-normal) | Mann-Withney U, N.S.
# roi 8 (73) - roi 9 (48) normality test p=6.656E-05 (sig. non-normal) normality test p=0.009 (sig. non-normal) | Mann-Withney U, N.S.
# roi 8 (73) - roi 10 (38) normality test p=6.656E-05 (sig. non-normal) normality test p=0.003 (sig. non-normal) | Mann-Withney U, N.S.
# roi 8 (73) - roi 11 (35) normality test p=6.656E-05 (sig. non-normal) normality test p=6.215E-05 (sig. non-normal) | Mann-Withney U, N.S.
# roi 8 (73) - roi 12 (68) normality test p=6.656E-05 (sig. non-normal) normality test p=4.604E-09 (sig. non-normal) | Mann-Withney U, N.S.
# roi 9 (48) - roi 10 (38) normality test p=0.009 (sig. non-normal) normality test p=0.003 (sig. non-normal) | Mann-Withney U, N.S.
# roi 9 (48) - roi 11 (35) normality test p=0.009 (sig. non-normal) normality test p=6.215E-05 (sig. non-normal) | Mann-Withney U, N.S.
# roi 9 (48) - roi 12 (68) normality test p=0.009 (sig. non-normal) normality test p=4.604E-09 (sig. non-normal) | Mann-Withney U, N.S.
# roi 10 (38) - roi 11 (35) normality test p=0.003 (sig. non-normal) normality test p=6.215E-05 (sig. non-normal) | Mann-Withney U, N.S.
# roi 10 (38) - roi 12 (68) normality test p=0.003 (sig. non-normal) normality test p=4.604E-09 (sig. non-normal) | Mann-Withney U, N.S.
# roi 11 (35) - roi 12 (68) normality test p=6.215E-05 (sig. non-normal) normality test p=4.604E-09 (sig. non-normal) | Mann-Withney U, N.S.
# class: narrow_lumen replicate: 2
# isthmus narrow_lumen
# roi 13 (53) - roi 14 (21) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 13 (53) - roi 15 (76) normality test p=0.001 (sig. non-normal) normality test p=0.003 (sig. non-normal) | Mann-Withney U, N.S.
# roi 13 (53) - roi 16 (37) normality test p=0.001 (sig. non-normal) normality test p=0.075 | Mann-Withney U, N.S.
# roi 13 (53) - roi 17 (21) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 13 (53) - roi 18 (18) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 14 (21) - roi 15 (76) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 14 (21) - roi 16 (37) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 14 (21) - roi 17 (21) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 14 (21) - roi 18 (18) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 15 (76) - roi 16 (37) normality test p=0.003 (sig. non-normal) normality test p=0.075 | Mann-Withney U, N.S.
# roi 15 (76) - roi 17 (21) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 15 (76) - roi 18 (18) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 16 (37) - roi 17 (21) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 16 (37) - roi 18 (18) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 17 (21) - roi 18 (18) n<25, using the Anderson-Darling test for k-samples, N.S.
# class: wide_lumen replicate: 2
# isthmus wide_lumen
# roi 19 (14) - roi 20 (15) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 19 (14) - roi 21 (16) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 19 (14) - roi 22 (0) SKIPPING pair due to scarcity of observations
# roi 19 (14) - roi 23 (0) SKIPPING pair due to scarcity of observations
# roi 19 (14) - roi 24 (0) SKIPPING pair due to scarcity of observations
# roi 20 (15) - roi 21 (16) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 20 (15) - roi 22 (0) SKIPPING pair due to scarcity of observations
# roi 20 (15) - roi 23 (0) SKIPPING pair due to scarcity of observations
# roi 20 (15) - roi 24 (0) SKIPPING pair due to scarcity of observations
# roi 21 (16) - roi 22 (0) SKIPPING pair due to scarcity of observations
# roi 21 (16) - roi 23 (0) SKIPPING pair due to scarcity of observations
# roi 21 (16) - roi 24 (0) SKIPPING pair due to scarcity of observations
# roi 22 (0) - roi 23 (0) SKIPPING pair due to scarcity of observations
# roi 22 (0) - roi 24 (0) SKIPPING pair due to scarcity of observations
# roi 23 (0) - roi 24 (0) SKIPPING pair due to scarcity of observations
# class: narrow_end replicate: 3
# isthmus narrow_end
# roi 1 (70) - roi 2 (70) normality test p=1.288E-05 (sig. non-normal) normality test p=1.286E-05 (sig. non-normal) | Mann-Withney U, N.S.
# roi 1 (70) - roi 3 (121) normality test p=1.288E-05 (sig. non-normal) normality test p=6.987E-21 (sig. non-normal) | Mann-Withney U, N.S.
# roi 1 (70) - roi 4 (71) normality test p=1.288E-05 (sig. non-normal) normality test p=2.316E-04 (sig. non-normal) | Mann-Withney U, N.S.
# roi 1 (70) - roi 5 (88) normality test p=1.288E-05 (sig. non-normal) normality test p=2.568E-07 (sig. non-normal) | Mann-Withney U, N.S.
# roi 1 (70) - roi 6 (95) normality test p=1.288E-05 (sig. non-normal) normality test p=8.036E-04 (sig. non-normal) | Mann-Withney U, N.S.
# roi 2 (70) - roi 3 (121) normality test p=1.286E-05 (sig. non-normal) normality test p=6.987E-21 (sig. non-normal) | Mann-Withney U, stat:3347.0 p: 0.0080, Reject H0
# roi 2 (70) - roi 4 (71) normality test p=1.286E-05 (sig. non-normal) normality test p=2.316E-04 (sig. non-normal) | Mann-Withney U, stat:2025.5 p: 0.0292, Reject H0
# roi 2 (70) - roi 5 (88) normality test p=1.286E-05 (sig. non-normal) normality test p=2.568E-07 (sig. non-normal) | Mann-Withney U, stat:2582.0 p: 0.0408, Reject H0
# roi 2 (70) - roi 6 (95) normality test p=1.286E-05 (sig. non-normal) normality test p=8.036E-04 (sig. non-normal) | Mann-Withney U, stat:2515.5 p: 0.0038, Reject H0
# roi 3 (121) - roi 4 (71) normality test p=6.987E-21 (sig. non-normal) normality test p=2.316E-04 (sig. non-normal) | Mann-Withney U, N.S.
# roi 3 (121) - roi 5 (88) normality test p=6.987E-21 (sig. non-normal) normality test p=2.568E-07 (sig. non-normal) | Mann-Withney U, N.S.
# roi 3 (121) - roi 6 (95) normality test p=6.987E-21 (sig. non-normal) normality test p=8.036E-04 (sig. non-normal) | Mann-Withney U, N.S.
# roi 4 (71) - roi 5 (88) normality test p=2.316E-04 (sig. non-normal) normality test p=2.568E-07 (sig. non-normal) | Mann-Withney U, N.S.
# roi 4 (71) - roi 6 (95) normality test p=2.316E-04 (sig. non-normal) normality test p=8.036E-04 (sig. non-normal) | Mann-Withney U, N.S.
# roi 5 (88) - roi 6 (95) normality test p=2.568E-07 (sig. non-normal) normality test p=8.036E-04 (sig. non-normal) | Mann-Withney U, N.S.
# class: wide_end replicate: 3
# isthmus wide_end
# roi 7 (36) - roi 8 (72) normality test p=0.136 normality test p=3.645E-05 (sig. non-normal) | Mann-Withney U, stat:1032.5 p: 0.0432, Reject H0
# roi 7 (36) - roi 9 (41) normality test p=0.136 normality test p=0.309 | Mann-Withney U, N.S.
# roi 7 (36) - roi 10 (46) normality test p=0.136 normality test p=0.006 (sig. non-normal) | Mann-Withney U, N.S.
# roi 7 (36) - roi 11 (30) normality test p=0.136 normality test p=0.152 | Mann-Withney U, N.S.
# roi 7 (36) - roi 12 (64) normality test p=0.136 normality test p=1.376E-05 (sig. non-normal) | Mann-Withney U, N.S.
# roi 8 (72) - roi 9 (41) normality test p=3.645E-05 (sig. non-normal) normality test p=0.309 | Mann-Withney U, N.S.
# roi 8 (72) - roi 10 (46) normality test p=3.645E-05 (sig. non-normal) normality test p=0.006 (sig. non-normal) | Mann-Withney U, N.S.
# roi 8 (72) - roi 11 (30) normality test p=3.645E-05 (sig. non-normal) normality test p=0.152 | Mann-Withney U, N.S.
# roi 8 (72) - roi 12 (64) normality test p=3.645E-05 (sig. non-normal) normality test p=1.376E-05 (sig. non-normal) | Mann-Withney U, N.S.
# roi 9 (41) - roi 10 (46) normality test p=0.309 normality test p=0.006 (sig. non-normal) | Mann-Withney U, N.S.
# roi 9 (41) - roi 11 (30) normality test p=0.309 normality test p=0.152 | Mann-Withney U, N.S.
# roi 9 (41) - roi 12 (64) normality test p=0.309 normality test p=1.376E-05 (sig. non-normal) | Mann-Withney U, N.S.
# roi 10 (46) - roi 11 (30) normality test p=0.006 (sig. non-normal) normality test p=0.152 | Mann-Withney U, N.S.
# roi 10 (46) - roi 12 (64) normality test p=0.006 (sig. non-normal) normality test p=1.376E-05 (sig. non-normal) | Mann-Withney U, N.S.
# roi 11 (30) - roi 12 (64) normality test p=0.152 normality test p=1.376E-05 (sig. non-normal) | Mann-Withney U, N.S.
# class: narrow_lumen replicate: 3
# isthmus narrow_lumen
# roi 13 (34) - roi 14 (31) normality test p=0.079 normality test p=0.370 | Mann-Withney U, N.S.
# roi 13 (34) - roi 15 (78) normality test p=0.079 normality test p=9.611E-07 (sig. non-normal) | Mann-Withney U, N.S.
# roi 13 (34) - roi 16 (25) normality test p=0.079 normality test p=0.155 | Mann-Withney U, N.S.
# roi 13 (34) - roi 17 (17) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 13 (34) - roi 18 (17) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 14 (31) - roi 15 (78) normality test p=0.370 normality test p=9.611E-07 (sig. non-normal) | Mann-Withney U, N.S.
# roi 14 (31) - roi 16 (25) normality test p=0.370 normality test p=0.155 | Mann-Withney U, N.S.
# roi 14 (31) - roi 17 (17) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 14 (31) - roi 18 (17) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 15 (78) - roi 16 (25) normality test p=9.611E-07 (sig. non-normal) normality test p=0.155 | Mann-Withney U, N.S.
# roi 15 (78) - roi 17 (17) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 15 (78) - roi 18 (17) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 16 (25) - roi 17 (17) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 16 (25) - roi 18 (17) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 17 (17) - roi 18 (17) n<25, using the Anderson-Darling test for k-samples, N.S.
# class: wide_lumen replicate: 3
# isthmus wide_lumen
# roi 19 (11) - roi 20 (10) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 19 (11) - roi 21 (20) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 19 (11) - roi 22 (0) SKIPPING pair due to scarcity of observations
# roi 19 (11) - roi 23 (0) SKIPPING pair due to scarcity of observations
# roi 19 (11) - roi 24 (0) SKIPPING pair due to scarcity of observations
# roi 20 (10) - roi 21 (20) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 20 (10) - roi 22 (0) SKIPPING pair due to scarcity of observations
# roi 20 (10) - roi 23 (0) SKIPPING pair due to scarcity of observations
# roi 20 (10) - roi 24 (0) SKIPPING pair due to scarcity of observations
# roi 21 (20) - roi 22 (0) SKIPPING pair due to scarcity of observations
# roi 21 (20) - roi 23 (0) SKIPPING pair due to scarcity of observations
# roi 21 (20) - roi 24 (0) SKIPPING pair due to scarcity of observations
# roi 22 (0) - roi 23 (0) SKIPPING pair due to scarcity of observations
# roi 22 (0) - roi 24 (0) SKIPPING pair due to scarcity of observations
# roi 23 (0) - roi 24 (0) SKIPPING pair due to scarcity of observations
# class: narrow_end replicate: 4
# isthmus narrow_end
# roi 1 (60) - roi 2 (63) normality test p=1.828E-04 (sig. non-normal) normality test p=9.664E-04 (sig. non-normal) | Mann-Withney U, N.S.
# roi 1 (60) - roi 3 (134) normality test p=1.828E-04 (sig. non-normal) normality test p=1.074E-08 (sig. non-normal) | Mann-Withney U, N.S.
# roi 1 (60) - roi 4 (68) normality test p=1.828E-04 (sig. non-normal) normality test p=6.126E-06 (sig. non-normal) | Mann-Withney U, N.S.
# roi 1 (60) - roi 5 (89) normality test p=1.828E-04 (sig. non-normal) normality test p=0.508 | Mann-Withney U, N.S.
# roi 1 (60) - roi 6 (63) normality test p=1.828E-04 (sig. non-normal) normality test p=0.007 (sig. non-normal) | Mann-Withney U, stat:1372.0 p: 0.0044, Reject H0
# roi 2 (63) - roi 3 (134) normality test p=9.664E-04 (sig. non-normal) normality test p=1.074E-08 (sig. non-normal) | Mann-Withney U, N.S.
# roi 2 (63) - roi 4 (68) normality test p=9.664E-04 (sig. non-normal) normality test p=6.126E-06 (sig. non-normal) | Mann-Withney U, N.S.
# roi 2 (63) - roi 5 (89) normality test p=9.664E-04 (sig. non-normal) normality test p=0.508 | Mann-Withney U, N.S.
# roi 2 (63) - roi 6 (63) normality test p=9.664E-04 (sig. non-normal) normality test p=0.007 (sig. non-normal) | Mann-Withney U, stat:1526.5 p: 0.0128, Reject H0
# roi 3 (134) - roi 4 (68) normality test p=1.074E-08 (sig. non-normal) normality test p=6.126E-06 (sig. non-normal) | Mann-Withney U, N.S.
# roi 3 (134) - roi 5 (89) normality test p=1.074E-08 (sig. non-normal) normality test p=0.508 | Mann-Withney U, N.S.
# roi 3 (134) - roi 6 (63) normality test p=1.074E-08 (sig. non-normal) normality test p=0.007 (sig. non-normal) | Mann-Withney U, stat:3197.5 p: 0.0031, Reject H0
# roi 4 (68) - roi 5 (89) normality test p=6.126E-06 (sig. non-normal) normality test p=0.508 | Mann-Withney U, N.S.
# roi 4 (68) - roi 6 (63) normality test p=6.126E-06 (sig. non-normal) normality test p=0.007 (sig. non-normal) | Mann-Withney U, stat:1647.5 p: 0.0114, Reject H0
# roi 5 (89) - roi 6 (63) normality test p=0.508 normality test p=0.007 (sig. non-normal) | Mann-Withney U, stat:2001.5 p: 0.0014, Reject H0
# class: wide_end replicate: 4
# isthmus wide_end
# roi 7 (28) - roi 8 (87) normality test p=0.232 normality test p=2.456E-16 (sig. non-normal) | Mann-Withney U, N.S.
# roi 7 (28) - roi 9 (46) normality test p=0.232 normality test p=1.344E-07 (sig. non-normal) | Mann-Withney U, N.S.
# roi 7 (28) - roi 10 (46) normality test p=0.232 normality test p=0.077 | Mann-Withney U, N.S.
# roi 7 (28) - roi 11 (30) normality test p=0.232 normality test p=0.167 | Mann-Withney U, N.S.
# roi 7 (28) - roi 12 (62) normality test p=0.232 normality test p=4.472E-05 (sig. non-normal) | Mann-Withney U, N.S.
# roi 8 (87) - roi 9 (46) normality test p=2.456E-16 (sig. non-normal) normality test p=1.344E-07 (sig. non-normal) | Mann-Withney U, stat:1646.0 p: 0.0468, Reject H0
# roi 8 (87) - roi 10 (46) normality test p=2.456E-16 (sig. non-normal) normality test p=0.077 | Mann-Withney U, N.S.
# roi 8 (87) - roi 11 (30) normality test p=2.456E-16 (sig. non-normal) normality test p=0.167 | Mann-Withney U, N.S.
# roi 8 (87) - roi 12 (62) normality test p=2.456E-16 (sig. non-normal) normality test p=4.472E-05 (sig. non-normal) | Mann-Withney U, N.S.
# roi 9 (46) - roi 10 (46) normality test p=1.344E-07 (sig. non-normal) normality test p=0.077 | Mann-Withney U, N.S.
# roi 9 (46) - roi 11 (30) normality test p=1.344E-07 (sig. non-normal) normality test p=0.167 | Mann-Withney U, N.S.
# roi 9 (46) - roi 12 (62) normality test p=1.344E-07 (sig. non-normal) normality test p=4.472E-05 (sig. non-normal) | Mann-Withney U, N.S.
# roi 10 (46) - roi 11 (30) normality test p=0.077 normality test p=0.167 | Mann-Withney U, N.S.
# roi 10 (46) - roi 12 (62) normality test p=0.077 normality test p=4.472E-05 (sig. non-normal) | Mann-Withney U, N.S.
# roi 11 (30) - roi 12 (62) normality test p=0.167 normality test p=4.472E-05 (sig. non-normal) | Mann-Withney U, N.S.
# class: narrow_lumen replicate: 4
# isthmus narrow_lumen
# roi 13 (39) - roi 14 (32) normality test p=0.037 (sig. non-normal) normality test p=0.015 (sig. non-normal) | Mann-Withney U, N.S.
# roi 13 (39) - roi 15 (81) normality test p=0.037 (sig. non-normal) normality test p=2.007E-11 (sig. non-normal) | Mann-Withney U, N.S.
# roi 13 (39) - roi 16 (27) normality test p=0.037 (sig. non-normal) normality test p=0.144 | Mann-Withney U, N.S.
# roi 13 (39) - roi 17 (19) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 13 (39) - roi 18 (11) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 14 (32) - roi 15 (81) normality test p=0.015 (sig. non-normal) normality test p=2.007E-11 (sig. non-normal) | Mann-Withney U, N.S.
# roi 14 (32) - roi 16 (27) normality test p=0.015 (sig. non-normal) normality test p=0.144 | Mann-Withney U, N.S.
# roi 14 (32) - roi 17 (19) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 14 (32) - roi 18 (11) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 15 (81) - roi 16 (27) normality test p=2.007E-11 (sig. non-normal) normality test p=0.144 | Mann-Withney U, N.S.
# roi 15 (81) - roi 17 (19) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 15 (81) - roi 18 (11) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 16 (27) - roi 17 (19) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 16 (27) - roi 18 (11) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 17 (19) - roi 18 (11) n<25, using the Anderson-Darling test for k-samples, N.S.
# class: wide_lumen replicate: 4
# isthmus wide_lumen
# roi 19 (19) - roi 20 (11) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 19 (19) - roi 21 (12) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 19 (19) - roi 22 (0) SKIPPING pair due to scarcity of observations
# roi 19 (19) - roi 23 (0) SKIPPING pair due to scarcity of observations
# roi 19 (19) - roi 24 (0) SKIPPING pair due to scarcity of observations
# roi 20 (11) - roi 21 (12) n<25, using the Anderson-Darling test for k-samples, N.S.
# roi 20 (11) - roi 22 (0) SKIPPING pair due to scarcity of observations
# roi 20 (11) - roi 23 (0) SKIPPING pair due to scarcity of observations
# roi 20 (11) - roi 24 (0) SKIPPING pair due to scarcity of observations
# roi 21 (12) - roi 22 (0) SKIPPING pair due to scarcity of observations
# roi 21 (12) - roi 23 (0) SKIPPING pair due to scarcity of observations
# roi 21 (12) - roi 24 (0) SKIPPING pair due to scarcity of observations
# roi 22 (0) - roi 23 (0) SKIPPING pair due to scarcity of observations
# roi 22 (0) - roi 24 (0) SKIPPING pair due to scarcity of observations
# roi 23 (0) - roi 24 (0) SKIPPING pair due to scarcity of observations
# Pairs tested: 240 skipped: 60 significant: 15 total: 315

# %%
most_repeating_significant_differences(significant_differences)
# Out:
# Significantly different pairs of ROI in more than one repeat:
# repeats: 2
# (2, 6) rep:3 p=0.0038, rep:4 p=0.0128,
# (7, 8) rep:1 p=0.0171, rep:3 p=0.0432,

# %%
# Differences between ROIs of the same class Ampulla
significant_differences = differences_between_same_class_rois_in_same_cross_section('ampulla1', 0.05)
# Out:
# H0: both samples were drawn from a population with the same distribution
# class: narrow_end replicate: 0
# ampulla1 narrow_end
# roi 1 (16) - roi 2 (13) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 1 (16) - roi 3 (14) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 1 (16) - roi 4 (15) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 1 (16) - roi 5 (12) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 1 (16) - roi 6 (13) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 2 (13) - roi 3 (14) n<25, using the Anderson-Darling test for k-samples significance level: 0.0412, Reject H0
# roi 2 (13) - roi 4 (15) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 2 (13) - roi 5 (12) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 2 (13) - roi 6 (13) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 3 (14) - roi 4 (15) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 3 (14) - roi 5 (12) n<25, using the Anderson-Darling test for k-samples significance level: 0.0213, Reject H0
# roi 3 (14) - roi 6 (13) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 4 (15) - roi 5 (12) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 4 (15) - roi 6 (13) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 5 (12) - roi 6 (13) n<25, using the Anderson-Darling test for k-samples N.S.
# class: wide_end replicate: 0
# ampulla1 wide_end
# roi 7 (7) - roi 8 (5) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 7 (7) - roi 9 (11) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 7 (7) - roi 10 (4) n<25, using the Anderson-Darling test for k-samples
# C:\Users\carlos2\Miniconda3\envs\data_analysis_py36\lib\site-packages\ipykernel_launcher.py:24: UserWarning: p-value capped: true value larger than 0.25
# N.S.
# roi 7 (7) - roi 11 (9) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 7 (7) - roi 12 (7) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 8 (5) - roi 9 (11) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 8 (5) - roi 10 (4) n<25, using the Anderson-Darling test for k-samples significance level: 0.0255, Reject H0
# roi 8 (5) - roi 11 (9) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 8 (5) - roi 12 (7) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 9 
(14) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 1 (13) - roi 3 (16) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 1 (13) - roi 4 (14) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 1 (13) - roi 5 (13) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 1 (13) - roi 6 (8) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 2 (14) - roi 3 (16) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 2 (14) - roi 4 (14) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 2 (14) - roi 5 (13) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 2 (14) - roi 6 (8) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 3 (16) - roi 4 (14) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 3 (16) - roi 5 (13) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 3 (16) - roi 6 (8) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 4 (14) - roi 5 (13) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 4 (14) - roi 6 (8) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 5 (13) - roi 6 (8) n<25, using the Anderson-Darling test for k-samples N.S.
# class: wide_end replicate: 4
# ampulla1 wide_end
# roi 7 (8) - roi 8 (4) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 7 (8) - roi 9 (7) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 7 (8) - roi 10 (8) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 7 (8) - roi 11 (8) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 7 (8) - roi 12 (5) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 8 (4) - roi 9 (7) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 8 (4) - roi 10 (8) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 8 (4) - roi 11 (8) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 8 (4) - roi 12 (5) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 9 (7) - roi 10 (8) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 9 (7) - roi 11 (8) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 9 (7) - roi 12 (5) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 10 (8) - roi 11 (8) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 10 (8) - roi 12 (5) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 11 (8) - roi 12 (5) n<25, using the Anderson-Darling test for k-samples N.S.
# class: narrow_lumen replicate: 4
# ampulla1 narrow_lumen
# roi 13 (14) - roi 14 (7) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 13 (14) - roi 15 (14) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 13 (14) - roi 16 (8) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 13 (14) - roi 17 (14) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 13 (14) - roi 18 (6) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 14 (7) - roi 15 (14) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 14 (7) - roi 16 (8) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 14 (7) - roi 17 (14) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 14 (7) - roi 18 (6) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 15 (14) - roi 16 (8) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 15 (14) - roi 17 (14) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 15 (14) - roi 18 (6) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 16 (8) - roi 17 (14) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 16 (8) - roi 18 (6) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 17 (14) - roi 18 (6) n<25, using the Anderson-Darling test for k-samples N.S.
# class: wide_lumen replicate: 4
# ampulla1 wide_lumen
# roi 19 (2) - roi 20 (0) SKIPPING pair due to scarcity of observations
# roi 19 (2) - roi 21 (2) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 19 (2) - roi 22 (5) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 19 (2) - roi 23 (2) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 19 (2) - roi 24 (2) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 20 (0) - roi 21 (2) SKIPPING pair due to scarcity of observations
# roi 20 (0) - roi 22 (5) SKIPPING pair due to scarcity of observations
# roi 20 (0) - roi 23 (2) SKIPPING pair due to scarcity of observations
# roi 20 (0) - roi 24 (2) SKIPPING pair due to scarcity of observations
# roi 21 (2) - roi 22 (5) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 21 (2) - roi 23 (2) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 21 (2) - roi 24 (2) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 22 (5) - roi 23 (2) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 22 (5) - roi 24 (2) n<25, using the Anderson-Darling test for k-samples N.S.
# roi 23 (2) - roi 24 (2) n<25, using the Anderson-Darling test for k-samples N.S.

# %%
most_repeating_significant_differences(significant_differences)
# Out:
# Significantly different pairs of ROI in more than one repeat:
# repeats: 2
# (10, 11) rep:1 p=0.0292, rep:3 p=0.0380,

# %%
# Differences between ROIs of distinct classes in the Isthmus
significant_differences = differences_between_non_same_class_rois_in_same_cross_section('isthmus', 0.05)

# %%
# Differences between Isth-Amp ROIs of the same category
s1 = 'isthmus'
s2 = 'ampulla1'
print('H0: both samples were drawn from a population with the same distribution')
alpha = 0.05
significant_differences = []

# identify those pairs with significant differences
for rep in range(5):
    differences = []
    for k,c in classes2['ordering']:
        print('section:', k, 'replicate:', rep)
        print('Isthmus-Ampulla')
        for i_roi, a_roi in product(classes2[s1][k], classes2[s2][k]):
            d_i = v2b_data.query(f"section=='{s1}' & replicate=={rep} & roi=={i_roi-1}")['radius_um']
            d_a = v2b_data.query(f"section=='{s2}' & replicate=={rep} & roi=={a_roi-1}")['radius_um']
            n_d_i, n_d_a= len(d_i), len(d_a)
            # Mann Withney U test, h0: assumption that both samples were drawn from a population with the same distribution
            # we reject h0 if there is evidence to suggest the samples were taken from two differt distributions
            x2, mwu_p = sp_stats.mannwhitneyu(d_i, d_a)
            x22, rank_p = sp_stats.ranksums(d_i, d_a)
            epps_stat, epps_p = sp_stats.epps_singleton_2samp(d_i, d_a)
            ks_stat, ks_p = sp_stats.ks_2samp(d_i, d_a)
            bm_stat, bm_p = sp_stats.brunnermunzel(d_i, d_a)

            print(f'roi {i_roi} ({n_d_i}) - roi {a_roi} ({n_d_a}), Mann-Withney U p: {mwu_p:.4f}, rank sums p: {rank_p:.4f}, Epps singleton 2 samp p: {epps_p:.4f}, KS 2 samp p: {ks_p:.4f}, Brunner-Munzel p:{bm_p:.4f}', end=' ')
            
            if mwu_p > alpha:
                print()
                pass
            else:
                differences.append([i_roi, a_roi, mwu_p])
                print(f'Reject h0')
    significant_differences.append(differences)

# identify the most repeating significant differences
reps = dict()
for r in range(len(significant_differences)):
    #print('In repeat',r)
    for d in significant_differences[r]:
        s = tuple(d[:2])
        if s not in reps:
            reps[s] = []
        reps[s].append(r)
# Out:
# H0: both samples were drawn from a population with the same distribution
# section: narrow_end replicate: 0
# Isthmus-Ampulla
# roi 1 (12) - roi 1 (271), Mann-Withney U p: 0.4534, rank sums p: 0.9053, Epps singleton 2 samp p: 0.0408, KS 2 samp p: 0.9871, Brunner-Munzel p:0.8983
# roi 1 (12) - roi 2 (133), Mann-Withney U p: 0.3386, rank sums p: 0.6746, Epps singleton 2 samp p: 0.0480, KS 2 samp p: 0.9383, Brunner-Munzel p:0.6424
# roi 1 (12) - roi 3 (160), Mann-Withney U p: 0.4108, rank sums p: 0.8193, Epps singleton 2 samp p: 0.0010, KS 2 samp p: 0.9317, Brunner-Munzel p:0.7988
# roi 1 (12) - roi 4 (198), Mann-Withney U p: 0.4034, rank sums p: 0.8049, Epps singleton 2 samp p: 0.0050, KS 2 samp p: 0.9764, Brunner-Munzel p:0.7907
# roi 1 (12) - roi 5 (119), Mann-Withney U p: 0.1212, rank sums p: 0.2408, Epps singleton 2 samp p: 0.0034, KS 2 samp p: 0.6956, Brunner-Munzel p:0.2105
# roi 1 (12) - roi 6 (87), Mann-Withney U p: 0.3678, rank sums p: 0.7315, Epps singleton 2 samp p: 0.0002, KS 2 samp p: 0.6838, Brunner-Munzel p:0.6704
# roi 2 (50) - roi 1 (271), Mann-Withney U p: 0.4169, rank sums p: 0.8332, Epps singleton 2 samp p: 0.7639, KS 2 samp p: 0.9413, Brunner-Munzel p:0.8339
# roi 2 (50) - roi 2 (133), Mann-Withney U p: 0.1623, rank sums p: 0.3239, Epps singleton 2 samp p: 0.5140, KS 2 samp p: 0.2202, Brunner-Munzel p:0.3181
# roi 2 (50) - roi 3 (160), Mann-Withney U p: 0.2134, rank sums p: 0.4261, Epps singleton 2 samp p: 0.3502, KS 2 samp p: 0.5594, Brunner-Munzel p:0.4193
# roi 2 (50) - roi 4 (198), Mann-Withney U p: 0.4648, rank sums p: 0.9288, Epps singleton 2 samp p: 0.7182, KS 2 samp p: 0.9960, Brunner-Munzel p:0.9288
# roi 2 (50) - roi 5 (119), Mann-Withney U p: 0.0126, rank sums p: 0.0251, Epps singleton 2 samp p: 0.0718, KS 2 samp p: 0.0319, Brunner-Munzel p:0.0256 Reject h0
# roi 2 (50) - roi 6 (87), Mann-Withney U p: 0.3462, rank sums p: 0.6907, Epps singleton 2 samp p: 0.1118, KS 2 samp p: 0.4724, Brunner-Munzel p:0.6818
# roi 21 (133) - roi 21 (1218), Mann-Withney U p: 0.2933, rank sums p: 0.5865, Epps singleton 2 samp p: 0.5886, KS 2 samp p: 0.8288, Brunner-Munzel p:0.6031
# roi 21 (133) - roi 22 (1482), Mann-Withney U p: 0.1176, rank sums p: 0.2352, Epps singleton 2 samp p: 0.4539, KS 2 samp p: 0.4715, Brunner-Munzel p:0.2568
# roi 21 (133) - roi 23 (693), Mann-Withney U p: 0.1117, rank sums p: 0.2234, Epps singleton 2 samp p: 0.3185, KS 2 samp p: 0.4366, Brunner-Munzel p:0.2440
# roi 21 (133) - roi 24 (923), Mann-Withney U p: 0.1085, rank sums p: 0.2170, Epps singleton 2 samp p: 0.5199, KS 2 samp p: 0.3722, Brunner-Munzel p:0.2347

# %% [markdown]
# ## Rois in same class

# %%
# rois in same class, all repeats together
def differences_between_rois_in_same_class_same_region(section):
    print('=='*20, '\n','ROIs in same class in', section)
    for class_name, class_colour in classes2['ordering']:
        print('Rois in', class_name, [roi for roi in classes2[section][class_name]])
        
        #for rep in range(5):
        #print('    repeat',rep+1, end=') ')
        dpr = []
        lengths = []
        for i_roi in classes2[section][class_name]:
            #d = v2b_data.query(f"section=='{section}' & replicate=={rep} & roi=={i_roi-1}")['radius_um']
            d = v2b_data.query(f"section=='{section}' & replicate in [0,1,2,3,4] & roi=={i_roi-1}")['radius_um']
            lengths.append((i_roi, len(d)))
            dpr.append(d)
        min_n = min([len(d) for d in dpr])
        # samples with less than 3 data points cannot be tested
        if min_n < 3:
            print(f'min_n ({min_n}) < 3, Attempting testing a subset of the data.', end=' ')
            original_dpr = dpr
            dpr = [d for d in dpr if len(d)>3]
            if len(dpr) < 2:
                print('There are not sufficient data points for testing')
                break
            print('Elements skipped:', [pair for pair in lengths if pair[1] < 3], end='\n\t      ')
            min_n = min([len(d) for d in dpr])

        # one way t-test assumes homoscedasticity, we must check the samples have the same variance
        parametric = False
        if min_n > 99:
            print(f'min_n ({min_n}) > 100, Normality not essential, skipping test', end=' ')
            # same variances?
            levene_stat, levene_p = sp_stats.levene(*dpr)
            if levene_p > 0.05:
                parametric = True
                print('Fail to reject Homoscedasticity', end=' ')
            else:
                print('Significantly different variances.', end=' ')

        elif min_n > 25:
            print(f'25 < min_n ({min_n}) < 100,', end='\n\t')
            if min([test_normality(d) for d in dpr]) < 0.05:
                print('\n\tAt least one distribution is significantly non-normal.', end=' ')
            else:
                print('\n\tDistributions not significantly different from normal', end=' ')
                # same variances?
                levene_stat, levene_p = sp_stats.levene(*dpr)
                if levene_p > 0.05:
                    parametric = True
                    print('Fail to reject Homoscedasticity', end=' ')
                else:
                    print('Significantly different variances.', end=' ')
        else:
            print(f'3 < min_n ({min_n}) < 25,', end=' ')

        if parametric:
            print('\n\tParametric test.\n\t', sp_stats.f_oneway(*dpr))
        else:
            print('\n\tNon-parametric test.\n\t', sp_stats.kruskal(*dpr))
        
        dprs = dpr
        pooled_dev = np.sqrt(np.sum([(r.count()-1) * (r.mean()**2) for r in dprs]) / (np.sum([r.count() for r in dprs]) - len(dprs)))
        print('Pooled deviation', pooled_dev,'\n-------')
                
differences_between_rois_in_same_class_same_region('ampulla1')
differences_between_rois_in_same_class_same_region('isthmus')
# Out:
# ========================================
#  ROIs in same class in ampulla1
# Rois in narrow_end [1, 2, 3, 4, 5, 6]
# 25 < min_n (55) < 100,
# 	normality test p=2.872E-14 (sig. non-normal) normality test p=1.705E-06 (sig. non-normal) normality test p=1.024E-04 (sig. non-normal) normality test p=0.010 (sig. non-normal) normality test p=2.063E-04 (sig. non-normal) normality test p=0.005 (sig. non-normal)
# 	At least one distribution is significantly non-normal.
# 	Non-parametric test.
# 	 KruskalResult(statistic=2.8671469946093606, pvalue=0.7204588897997898)
# Pooled deviation 0.10164438796586625
# -------
# Rois in wide_end [7, 8, 9, 10, 11, 12]
# 3 < min_n (22) < 25,
# 	Non-parametric test.
# 	 KruskalResult(statistic=7.224399809787691, pvalue=0.20447917650232983)
# Pooled deviation 0.09937201741476544
# -------
# Rois in narrow_lumen [13, 14, 15, 16, 17, 18]
# 3 < min_n (21) < 25,
# 	Non-parametric test.
# 	 KruskalResult(statistic=1.0951460331021663, pvalue=0.9545324225306633)
# Pooled deviation 0.10182663018251106
# -------
# Rois in wide_lumen [19, 20, 21, 22, 23, 24]
# min_n (2) < 3, Attempting testing a subset of the data. Elements skipped: [(20, 2)]
# 	      3 < min_n (6) < 25,
# 	Non-parametric test.
# 	 KruskalResult(statistic=2.8920021080966047, pvalue=0.5760581976196594)
# Pooled deviation 0.108002539178995
# -------
# ========================================
#  ROIs in same class in isthmus
# Rois in narrow_end [1, 2, 3, 4, 5, 6]
# min_n (324) > 100, Normality not essential, skipping test Fail to reject Homoscedasticity
# 	Parametric test.
# 	 F_onewayResult(statistic=0.584422766241637, pvalue=0.7119850341795706)
# Pooled deviation 0.10095306121919233
# -------
# Rois in wide_end [7, 8, 9]
# min_n (161) > 100, Normality not essential, skipping test Fail to reject Homoscedasticity
# 	Parametric test.
# 	 F_onewayResult(statistic=0.42821482023200513, pvalue=0.651825699158757)
# Pooled deviation 0.10260397905317965
# -------
# Rois in narrow_lumen [10, 11, 12, 13, 14, 15]
# min_n (141) > 100, Normality not essential, skipping test Fail to reject Homoscedasticity
# 	Parametric test.
# 	 F_onewayResult(statistic=0.6730765311093613, pvalue=0.6439133123526719)
# Pooled deviation 0.09924918646269047
# -------
# Rois in wide_lumen [16, 17, 18, 19, 20, 21]
# 25 < min_n (61) < 100,
# 	normality test p=3.431E-12 (sig. non-normal) normality test p=4.315E-06 (sig. non-normal) normality test p=0.168 normality test p=1.248E-07 (sig. non-normal) normality test p=9.428E-04 (sig. non-normal) normality test p=0.002 (sig. non-normal)
# 	At least one distribution is significantly non-normal.
# 	Non-parametric test.
# 	 KruskalResult(statistic=5.9771676978116774, pvalue=0.3084469454143444)
# Pooled deviation 0.09711066222535279
# -------

# %%
# rois in same class, per repeat
def differences_between_rois_in_same_class_same_region(section):
    print('=='*20, '\n','ROIs in same class in', section)
    for class_name, class_colour in classes2['ordering']:
        print('Rois in', class_name, [roi for roi in classes2[section][class_name]])
        
        for rep in range(5):
            print('    repeat',rep+1, end=') ')
            dpr = []
            lengths = []
            for i_roi in classes2[section][class_name]:
                d = v2b_data.query(f"section=='{section}' & replicate=={rep} & roi=={i_roi-1}")['radius_um']
                #d = v2b_data.query(f"section=='{section}' & replicate in [0,1,2,3,4] & roi=={i_roi-1}")['radius_um']
                lengths.append((i_roi, len(d)))
                dpr.append(d)
            min_n = min([len(d) for d in dpr])
            # samples with less than 3 data points cannot be tested
            if min_n < 3:
                print(f'min_n ({min_n}) < 3, Attempting testing a subset of the data.', end=' ')
                original_dpr = dpr
                dpr = [d for d in dpr if len(d)>3]
                if len(dpr) < 2:
                    print('There are not sufficient data points for testing')
                    break
                print('Elements skipped:', [pair for pair in lengths if pair[1] < 3], end='\n\t      ')
                min_n = min([len(d) for d in dpr])

            # one way t-test assumes homoscedasticity, we must check the samples have the same variance
            parametric = False
            if min_n > 99:
                print(f'min_n ({min_n}) > 100, Normality not essential, skipping test', end=' ')
                # same variances?
                levene_stat, levene_p = sp_stats.levene(*dpr)
                if levene_p > 0.05:
                    parametric = True
                    print('Fail to reject Homoscedasticity', end=' ')
                else:
                    print('Significantly different variances.', end=' ')

            elif min_n > 25:
                print(f'25 < min_n ({min_n}) < 100,', end='\n\t')
                if min([test_normality(d) for d in dpr]) < 0.05:
                    print('\n\tAt least one distribution is significantly non-normal.', end=' ')
                else:
                    print('\n\tDistributions not significantly different from normal', end=' ')
                    # same variances?
                    levene_stat, levene_p = sp_stats.levene(*dpr)
                    if levene_p > 0.05:
                        parametric = True
                        print('Fail to reject Homoscedasticity', end=' ')
                    else:
                        print('Significantly different variances.', end=' ')
            else:
                print(f'3 < min_n ({min_n}) < 25,', end=' ')

            if parametric:
                print('\n\tParametric test.\n\t', sp_stats.f_oneway(*dpr))
            else:
                print('\n\tNon-parametric test.\n\t', sp_stats.kruskal(*dpr))
                
differences_between_rois_in_same_class_same_region('ampulla1')
differences_between_rois_in_same_class_same_region('isthmus')
# Out:
# ========================================
#  ROIs in same class in ampulla1
# Rois in narrow_end [1, 2, 3, 4, 5, 6]
#     repeat 1) 3 < min_n (12) < 25,
# 	Non-parametric test.
# 	 KruskalResult(statistic=6.264950609744168, pvalue=0.28128505839557183)
#     repeat 2) 3 < min_n (7) < 25,
# 	Non-parametric test.
# 	 KruskalResult(statistic=6.812084813077343, pvalue=0.23499511957662034)
#     repeat 3) 3 < min_n (10) < 25,
# 	Non-parametric test.
# 	 KruskalResult(statistic=6.145245569825527, pvalue=0.2923414009515786)
#     repeat 4) 3 < min_n (13) < 25,
# 	Non-parametric test.
# 	 KruskalResult(statistic=5.322263481002435, pvalue=0.37782899461252856)
#     repeat 5) 3 < min_n (8) < 25,
# 	Non-parametric test.
# 	 KruskalResult(statistic=3.99043691190736, pvalue=0.5507936269626696)
# Rois in wide_end [7, 8, 9, 10, 11, 12]
#     repeat 1) 3 < min_n (4) < 25,
# 	Non-parametric test.
# 	 KruskalResult(statistic=5.922654256134874, pvalue=0.31381791122878894)
#     repeat 2) min_n (2) < 3, Attempting testing a subset of the data. Elements skipped: [(8, 2)]
# 	      3 < min_n (6) < 25,
# 	Non-parametric test.
# 	 KruskalResult(statistic=11.933848091561238, pvalue=0.007613238732162838)
#     repeat 3) 3 < min_n (3) < 25,
# 	Non-parametric test.
# 	 KruskalResult(statistic=4.5795439164112235, pvalue=0.4693117865136378)
#     repeat 4) 3 < min_n (3) < 25,
# 	Non-parametric test.
# 	 KruskalResult(statistic=3.7033779652726992, pvalue=0.5928613504094805)
#     repeat 5) 3 < min_n (4) < 25,
# 	Non-parametric test.
# 	 KruskalResult(statistic=6.592613194649234, pvalue=0.25274308260865047)
# Rois in narrow_lumen [13, 14, 15, 16, 17, 18]
#     repeat 1) 3 < min_n (5) < 25,
# 	Non-parametric test.
# 	 KruskalResult(statistic=1.8701096144823863, pvalue=0.8668100800130196)
#     repeat 2) 3 < min_n (4) < 25,
# 	Non-parametric test.
# 	 KruskalResult(statistic=8.693718409778729, pvalue=0.12192220762937005)
#     repeat 3) 3 < min_n (3) < 25,
# 	Non-parametric test.
# 	 KruskalResult(statistic=5.351659550602825, pvalue=0.3744861773003071)
#     repeat 4) min_n (2) < 3, Attempting testing a subset of the data. Elements skipped: [(18, 2)]
# 	      3 < min_n (8) < 25,
# 	Non-parametric test.
# 	 KruskalResult(statistic=5.670183043112581, pvalue=0.22517031170334603)
#     repeat 5) 3 < min_n (6) < 25,
# 	Non-parametric test.
# 	 KruskalResult(statistic=3.2470065829727677, pvalue=0.661964200253714)
# Rois in wide_lumen [19, 20, 21, 22, 23, 24]
#     repeat 1) min_n (1) < 3, Attempting testing a subset of the data. There are not sufficient data points for testing
# ========================================
#  ROIs in same class in isthmus
# Rois in narrow_end [1, 2, 3, 4, 5, 6]
#     repeat 1) 25 < min_n (61) < 100,
# 	normality test p=0.009 (sig. non-normal) normality test p=4.137E-07 (sig. non-normal) normality test p=1.523E-11 (sig. non-normal) normality test p=4.235E-04 (sig. non-normal) normality test p=6.738E-08 (sig. non-normal) normality test p=0.650
# 	At least one distribution is significantly non-normal.
# 	Non-parametric test.
# 	 KruskalResult(statistic=1.9095518572312111, pvalue=0.8615133986213208)
#     repeat 2) 25 < min_n (66) < 100,
# 	normality test p=2.766E-07 (sig. non-normal) normality test p=1.118E-06 (sig. non-normal) normality test p=3.775E-09 (sig. non-normal) normality test p=1.232E-04 (sig. non-normal) normality test p=0.004 (sig. non-normal) normality test p=5.666E-04 (sig. non-normal)
# 	At least one distribution is significantly non-normal.
# 	Non-parametric test.
# 	 KruskalResult(statistic=4.729356506650497, pvalue=0.44979432240057216)
#     repeat 3) 25 < min_n (62) < 100,
# 	normality test p=2.768E-10 (sig. non-normal) normality test p=1.590E-04 (sig. non-normal) normality test p=2.430E-05 (sig. non-normal) normality test p=3.021E-05 (sig. non-normal) normality test p=1.284E-07 (sig. non-normal) normality test p=0.005 (sig. non-normal)
# 	At least one distribution is significantly non-normal.
# 	Non-parametric test.
# 	 KruskalResult(statistic=3.589842828723446, pvalue=0.6098389888208522)
#     repeat 4) 25 < min_n (70) < 100,
# 	normality test p=1.288E-05 (sig. non-normal) normality test p=1.286E-05 (sig. non-normal) normality test p=6.987E-21 (sig. non-normal) normality test p=2.316E-04 (sig. non-normal) normality test p=2.568E-07 (sig. non-normal) normality test p=8.036E-04 (sig. non-normal)
# 	At least one distribution is significantly non-normal.
# 	Non-parametric test.
# 	 KruskalResult(statistic=8.148175455919437, pvalue=0.14825624129957227)
#     repeat 5) 25 < min_n (60) < 100,
# 	normality test p=1.828E-04 (sig. non-normal) normality test p=9.664E-04 (sig. non-normal) normality test p=1.074E-08 (sig. non-normal) normality test p=6.126E-06 (sig. non-normal) normality test p=0.508 normality test p=0.007 (sig. non-normal)
# 	At least one distribution is significantly non-normal.
# 	Non-parametric test.
# 	 KruskalResult(statistic=10.866357084687436, pvalue=0.054095067923736244)
# Rois in wide_end [7, 8, 9]
#     repeat 1) 25 < min_n (33) < 100,
# 	normality test p=0.030 (sig. non-normal) normality test p=0.002 (sig. non-normal) normality test p=0.007 (sig. non-normal)
# 	At least one distribution is significantly non-normal.
# 	Non-parametric test.
# 	 KruskalResult(statistic=0.5359119057915133, pvalue=0.7649414738176625)
#     repeat 2) 25 < min_n (34) < 100,
# 	normality test p=0.322 normality test p=4.908E-05 (sig. non-normal) normality test p=0.320
# 	At least one distribution is significantly non-normal.
# 	Non-parametric test.
# 	 KruskalResult(statistic=4.687468723627024, pvalue=0.09596858680792138)
#     repeat 3) 25 < min_n (30) < 100,
# 	normality test p=0.009 (sig. non-normal) normality test p=6.656E-05 (sig. non-normal) normality test p=0.009 (sig. non-normal)
# 	At least one distribution is significantly non-normal.
# 	Non-parametric test.
# 	 KruskalResult(statistic=0.35841925593342044, pvalue=0.8359306465869774)
#     repeat 4) 25 < min_n (36) < 100,
# 	normality test p=0.136 normality test p=3.645E-05 (sig. non-normal) normality test p=0.309
# 	At least one distribution is significantly non-normal.
# 	Non-parametric test.
# 	 KruskalResult(statistic=2.947839862365703, pvalue=0.2290259573031432)
#     repeat 5) 25 < min_n (28) < 100,
# 	normality test p=0.232 normality test p=2.456E-16 (sig. non-normal) normality test p=1.344E-07 (sig. non-normal)
# 	At least one distribution is significantly non-normal.
# 	Non-parametric test.
# 	 KruskalResult(statistic=2.5761840102215237, pvalue=0.2757964997098695)
# Rois in narrow_lumen [10, 11, 12, 13, 14, 15]
#     repeat 1) 25 < min_n (29) < 100,
# 	normality test p=2.590E-10 (sig. non-normal) normality test p=0.009 (sig. non-normal) normality test p=1.326E-08 (sig. non-normal) normality test p=0.002 (sig. non-normal) normality test p=0.006 (sig. non-normal) normality test p=0.001 (sig. non-normal)
# 	At least one distribution is significantly non-normal.
# 	Non-parametric test.
# 	 KruskalResult(statistic=2.550695179597055, pvalue=0.7688416707681041)
#     repeat 2) 3 < min_n (21) < 25,
# 	Non-parametric test.
# 	 KruskalResult(statistic=4.3781985052373695, pvalue=0.4963435268971139)
#     repeat 3) 3 < min_n (21) < 25,
# 	Non-parametric test.
# 	 KruskalResult(statistic=3.5937458770044284, pvalue=0.609252564915761)
#     repeat 4) 25 < min_n (30) < 100,
# 	normality test p=0.006 (sig. non-normal) normality test p=0.152 normality test p=1.376E-05 (sig. non-normal) normality test p=0.079 normality test p=0.370 normality test p=9.611E-07 (sig. non-normal)
# 	At least one distribution is significantly non-normal.
# 	Non-parametric test.
# 	 KruskalResult(statistic=4.290821467786365, pvalue=0.5083485084613428)
#     repeat 5) 25 < min_n (30) < 100,
# 	normality test p=0.077 normality test p=0.167 normality test p=4.472E-05 (sig. non-normal) normality test p=0.037 (sig. non-normal) normality test p=0.015 (sig. non-normal) normality test p=2.007E-11 (sig. non-normal)
# 	At least one distribution is significantly non-normal.
# 	Non-parametric test.
# 	 KruskalResult(statistic=1.4644966068714913, pvalue=0.9171301731546299)
# Rois in wide_lumen [16, 17, 18, 19, 20, 21]
#     repeat 1) 3 < min_n (10) < 25,
# 	Non-parametric test.
# 	 KruskalResult(statistic=0.7518116191369897, pvalue=0.9800046024704706)
#     repeat 2) 3 < min_n (10) < 25,
# 	Non-parametric test.
# 	 KruskalResult(statistic=7.225547275608172, pvalue=0.20439921151156704)
#     repeat 3) 3 < min_n (14) < 25,
# 	Non-parametric test.
# 	 KruskalResult(statistic=4.247316022908965, pvalue=0.5143854029560504)
#     repeat 4) 3 < min_n (10) < 25,
# 	Non-parametric test.
# 	 KruskalResult(statistic=2.6162660039976466, pvalue=0.7588923233236157)
#     repeat 5) 3 < min_n (11) < 25,
# 	Non-parametric test.
# 	 KruskalResult(statistic=2.094747812732756, pvalue=0.8358856683651126)

# %% [markdown]
# ## Rois in different class

# %%
[p for p in combinations([t[0] for t in classes2['ordering']], 2)]
# Out:
# [('narrow_end', 'wide_end'),
#  ('narrow_end', 'narrow_lumen'),
#  ('narrow_end', 'wide_lumen'),
#  ('wide_end', 'narrow_lumen'),
#  ('wide_end', 'wide_lumen'),
#  ('narrow_lumen', 'wide_lumen')]

# %%
a = [np.random.rand(20), np.random.rand(22), np.random.rand(28)]
b = [np.random.rand(35), np.random.rand(29)]

# %%
sp_stats.f_oneway(*a, *b), sp_stats.kruskal(*a, *b)
# Out:
# (F_onewayResult(statistic=1.4929413282705002, pvalue=0.2080911689680226),
#  KruskalResult(statistic=6.318128524417716, pvalue=0.17661657302852227))

# %%
min([test_normality(d) for d in a + b]) < 0.05
# Out:
# normality test p=0.185 normality test p=0.065 normality test p=4.775E-05 (sig. non-normal) normality test p=0.064 normality test p=0.029 (sig. non-normal)
# True

# %%
# rois in different class
def differences_between_rois_in_different_class_same_region(section):
    """
    Test for significant differences between distinct ROI classes by using all the elements in each class
    In order to test each class against the others, we need to use combinations of the classes
    """
    print('=='*20, '\n','ROIs in different class in', section)
    for roi_class_1, roi_class_2 in [p for p in combinations([t[0] for t in classes2['ordering']], 2)]:
        print('Rois in', roi_class_1, [roi for roi in classes2[section][roi_class_1]])
        print('Rois in', roi_class_2, [roi for roi in classes2[section][roi_class_2]])
        
        for rep in range(5):
            dpr1, dpr2 = [], []
            lengths1, lengths2 = [], []
            print('    repeat',rep+1, end=') ')
            for i_roi in classes2[section][roi_class_1]:
                d1 = v2b_data.query(f"section=='{section}' & replicate=={rep} & roi=={i_roi-1}")['radius_um']
                lengths1.append((i_roi, len(d1)))
                dpr1.append(d1)
            for i_roi in classes2[section][roi_class_2]:
                d2 = v2b_data.query(f"section=='{section}' & replicate=={rep} & roi=={i_roi-1}")['radius_um']
                lengths2.append((i_roi, len(d2)))
                dpr2.append(d2)

            # all the test must be done to both lists of data
            min_n1 = min([len(d) for d in dpr1])
            min_n2 = min([len(d) for d in dpr2])
            # samples with less than 3 data points cannot be tested
            if min_n1 < 3:
                print('min_n1 < 3, Attempting testing a subset of the data.', end=' ')
                original_dpr1 = dpr1
                dpr1 = [d for d in dpr1 if len(d)>3]
                print('Elements skipped:', [pair for pair in lengths1 if pair[1] < 3], end='\n\t      ')
                if len(dpr1) < 2:
                    print('There are not sufficient data points for testing')
                    break
                min_n1 = min([len(d) for d in dpr1])
            if min_n2 < 3:
                print('min_n2 < 3, Attempting testing a subset of the data.', end=' ')
                original_dpr2 = dpr2
                dpr2 = [d for d in dpr2 if len(d)>3]
                print('Elements skipped:', [pair for pair in lengths2 if pair[1] < 3], end='\n\t      ')
                if len(dpr2) < 2:
                    print('There are not sufficient data points for testing')
                    break
                min_n2 = min([len(d) for d in dpr2])

            # one way t-test assumes homoscedasticity, we must check the samples have the same variance
            parametric = False
            if min_n1 > 99 and min_n2 > 99:
                print(f'min_n1 ({min_n1}) > 100 and min_n2 ({min_n2}) > 99, Normality not highly important, skipping test', end=' ')
                # same variances?
                levene_stat, levene_p = sp_stats.levene(*dpr1, *dpr2)
                if levene_p > 0.05:
                    parametric = True
                    print('Fail to reject Homoscedasticity', end=' ')
                else:
                    print('Significantly different variances.', end=' ')
                    
            elif min_n1 > 25 and min_n2 > 25:
                print(f'25 < min_n1 ({min_n1}), min_n2 ({min_n2}) < 100,', end='\n\t')
                if min([test_normality(d) for d in dpr1 + dpr2]) < 0.05:
                    print('\n\tAt least one distribution is significantly non-normal.', end=' ')
                else:
                    print('\n\tDistributions not significantly different from normal', end=' ')
                    # same variances?
                    levene_stat, levene_p = sp_stats.levene(*dpr1, *dpr2)
                    if levene_p > 0.05:
                        parametric = True
                        print('Fail to reject Homoscedasticity', end=' ')
                    else:
                        print('Significantly different variances.', end=' ')
            else:
                print(f'3 < min_n ({min_n}) < 25,', end=' ')
            
            if parametric:
                res = sp_stats.f_oneway(*dpr1, *dpr2)
                print(f'\n\tParametric test (one-way ANOVA). {res[1]:.4f}', end=' ')
            else:
                res = sp_stats.kruskal(*dpr1, *dpr2)
                print(f'\n\tNon-parametric test (Kruskal-Wallis). {res[1]:.4f}', end=' ')
            print('N.S.' if res[1] > alpha else 'Significant differences. Reject H0')
            dprs = dpr1 + dpr2
            pooled_dev = np.sqrt(np.sum([(r.count()-1) * (r.mean()**2) for r in dprs]) / (np.sum([r.count() for r in dprs]) - len(dprs)))
            print('Pooled deviation', pooled_dev,'\n-------')

differences_between_rois_in_different_class_same_region('ampulla1')
differences_between_rois_in_different_class_same_region('isthmus')
# Out:
# ========================================
#  ROIs in different class in ampulla1
# Rois in narrow_end [1, 2, 3, 4, 5, 6]
# Rois in wide_end [7, 8, 9, 10, 11, 12]
#     repeat 1) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.3143 N.S.
# Pooled deviation 0.10438681225140536
# -------
#     repeat 2) min_n2 < 3, Attempting testing a subset of the data. Elements skipped: [(8, 2)]
# 	      3 < min_n (6) < 25,
# 	Non-parametric test. 0.0202 Significant differences. Reject H0
# Pooled deviation 0.09735700729758767
# -------
#     repeat 3) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.3781 N.S.
# Pooled deviation 0.10085970770105468
# -------
#     repeat 4) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.2148 N.S.
# Pooled deviation 0.09960375410949662
# -------
#     repeat 5) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.4711 N.S.
# Pooled deviation 0.10663371494757747
# -------
# Rois in narrow_end [1, 2, 3, 4, 5, 6]
# Rois in narrow_lumen [13, 14, 15, 16, 17, 18]
#     repeat 1) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.5841 N.S.
# Pooled deviation 0.10277910441401455
# -------
#     repeat 2) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.1437 N.S.
# Pooled deviation 0.09591924254585592
# -------
#     repeat 3) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.3508 N.S.
# Pooled deviation 0.09894122689516588
# -------
#     repeat 4) min_n2 < 3, Attempting testing a subset of the data. Elements skipped: [(18, 2)]
# 	      3 < min_n (6) < 25,
# 	Non-parametric test. 0.3370 N.S.
# Pooled deviation 0.10562105167113144
# -------
#     repeat 5) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.7126 N.S.
# Pooled deviation 0.10692126673386532
# -------
# Rois in narrow_end [1, 2, 3, 4, 5, 6]
# Rois in wide_lumen [19, 20, 21, 22, 23, 24]
#     repeat 1) min_n2 < 3, Attempting testing a subset of the data. Elements skipped: [(20, 1), (21, 1), (22, 2), (23, 1), (24, 1)]
# 	      There are not sufficient data points for testing
# Rois in wide_end [7, 8, 9, 10, 11, 12]
# Rois in narrow_lumen [13, 14, 15, 16, 17, 18]
#     repeat 1) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.7304 N.S.
# Pooled deviation 0.09994931733570028
# -------
#     repeat 2) min_n1 < 3, Attempting testing a subset of the data. Elements skipped: [(8, 2)]
# 	      3 < min_n (6) < 25,
# 	Non-parametric test. 0.0124 Significant differences. Reject H0
# Pooled deviation 0.09775414294466586
# -------
#     repeat 3) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.3830 N.S.
# Pooled deviation 0.10334769799193551
# -------
#     repeat 4) min_n2 < 3, Attempting testing a subset of the data. Elements skipped: [(18, 2)]
# 	      3 < min_n (6) < 25,
# 	Non-parametric test. 0.0774 N.S.
# Pooled deviation 0.10267130941402006
# -------
#     repeat 5) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.5743 N.S.
# Pooled deviation 0.10389787371344578
# -------
# Rois in wide_end [7, 8, 9, 10, 11, 12]
# Rois in wide_lumen [19, 20, 21, 22, 23, 24]
#     repeat 1) min_n2 < 3, Attempting testing a subset of the data. Elements skipped: [(20, 1), (21, 1), (22, 2), (23, 1), (24, 1)]
# 	      There are not sufficient data points for testing
# Rois in narrow_lumen [13, 14, 15, 16, 17, 18]
# Rois in wide_lumen [19, 20, 21, 22, 23, 24]
#     repeat 1) min_n2 < 3, Attempting testing a subset of the data. Elements skipped: [(20, 1), (21, 1), (22, 2), (23, 1), (24, 1)]
# 	      There are not sufficient data points for testing
# ========================================
#  ROIs in different class in isthmus
# Rois in narrow_end [1, 2, 3, 4, 5, 6]
# Rois in wide_end [7, 8, 9]
#     repeat 1) 25 < min_n1 (61), min_n2 (33) < 100,
# 	normality test p=0.009 (sig. non-normal) normality test p=4.137E-07 (sig. non-normal) normality test p=1.523E-11 (sig. non-normal) normality test p=4.235E-04 (sig. non-normal) normality test p=6.738E-08 (sig. non-normal) normality test p=0.650 normality test p=0.030 (sig. non-normal) normality test p=0.002 (sig. non-normal) normality test p=0.007 (sig. non-normal)
# 	At least one distribution is significantly non-normal.
# 	Non-parametric test. 0.9585 N.S.
# Pooled deviation 0.10132022409954901
# -------
#     repeat 2) 25 < min_n1 (66), min_n2 (34) < 100,
# 	normality test p=2.766E-07 (sig. non-normal) normality test p=1.118E-06 (sig. non-normal) normality test p=3.775E-09 (sig. non-normal) normality test p=1.232E-04 (sig. non-normal) normality test p=0.004 (sig. non-normal) normality test p=5.666E-04 (sig. non-normal) normality test p=0.322 normality test p=4.908E-05 (sig. non-normal) normality test p=0.320
# 	At least one distribution is significantly non-normal.
# 	Non-parametric test. 0.2567 N.S.
# Pooled deviation 0.10267190054722788
# -------
#     repeat 3) 25 < min_n1 (62), min_n2 (30) < 100,
# 	normality test p=2.768E-10 (sig. non-normal) normality test p=1.590E-04 (sig. non-normal) normality test p=2.430E-05 (sig. non-normal) normality test p=3.021E-05 (sig. non-normal) normality test p=1.284E-07 (sig. non-normal) normality test p=0.005 (sig. non-normal) normality test p=0.009 (sig. non-normal) normality test p=6.656E-05 (sig. non-normal) normality test p=0.009 (sig. non-normal)
# 	At least one distribution is significantly non-normal.
# 	Non-parametric test. 0.6524 N.S.
# Pooled deviation 0.10024352962916995
# -------
#     repeat 4) 25 < min_n1 (70), min_n2 (36) < 100,
# 	normality test p=1.288E-05 (sig. non-normal) normality test p=1.286E-05 (sig. non-normal) normality test p=6.987E-21 (sig. non-normal) normality test p=2.316E-04 (sig. non-normal) normality test p=2.568E-07 (sig. non-normal) normality test p=8.036E-04 (sig. non-normal) normality test p=0.136 normality test p=3.645E-05 (sig. non-normal) normality test p=0.309
# 	At least one distribution is significantly non-normal.
# 	Non-parametric test. 0.1657 N.S.
# Pooled deviation 0.10199806687800438
# -------
#     repeat 5) 25 < min_n1 (60), min_n2 (28) < 100,
# 	normality test p=1.828E-04 (sig. non-normal) normality test p=9.664E-04 (sig. non-normal) normality test p=1.074E-08 (sig. non-normal) normality test p=6.126E-06 (sig. non-normal) normality test p=0.508 normality test p=0.007 (sig. non-normal) normality test p=0.232 normality test p=2.456E-16 (sig. non-normal) normality test p=1.344E-07 (sig. non-normal)
# 	At least one distribution is significantly non-normal.
# 	Non-parametric test. 0.0934 N.S.
# Pooled deviation 0.10080566540278843
# -------
# Rois in narrow_end [1, 2, 3, 4, 5, 6]
# Rois in narrow_lumen [10, 11, 12, 13, 14, 15]
#     repeat 1) 25 < min_n1 (61), min_n2 (29) < 100,
# 	normality test p=0.009 (sig. non-normal) normality test p=4.137E-07 (sig. non-normal) normality test p=1.523E-11 (sig. non-normal) normality test p=4.235E-04 (sig. non-normal) normality test p=6.738E-08 (sig. non-normal) normality test p=0.650 normality test p=2.590E-10 (sig. non-normal) normality test p=0.009 (sig. non-normal) normality test p=1.326E-08 (sig. non-normal) normality test p=0.002 (sig. non-normal) normality test p=0.006 (sig. non-normal) normality test p=0.001 (sig. non-normal)
# 	At least one distribution is significantly non-normal.
# 	Non-parametric test. 0.9231 N.S.
# Pooled deviation 0.10020649668265194
# -------
#     repeat 2) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.5896 N.S.
# Pooled deviation 0.10176761951861714
# -------
#     repeat 3) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.7897 N.S.
# Pooled deviation 0.09886466113643243
# -------
#     repeat 4) 25 < min_n1 (70), min_n2 (30) < 100,
# 	normality test p=1.288E-05 (sig. non-normal) normality test p=1.286E-05 (sig. non-normal) normality test p=6.987E-21 (sig. non-normal) normality test p=2.316E-04 (sig. non-normal) normality test p=2.568E-07 (sig. non-normal) normality test p=8.036E-04 (sig. non-normal) normality test p=0.006 (sig. non-normal) normality test p=0.152 normality test p=1.376E-05 (sig. non-normal) normality test p=0.079 normality test p=0.370 normality test p=9.611E-07 (sig. non-normal)
# 	At least one distribution is significantly non-normal.
# 	Non-parametric test. 0.0798 N.S.
# Pooled deviation 0.10048074446540191
# -------
#     repeat 5) 25 < min_n1 (60), min_n2 (30) < 100,
# 	normality test p=1.828E-04 (sig. non-normal) normality test p=9.664E-04 (sig. non-normal) normality test p=1.074E-08 (sig. non-normal) normality test p=6.126E-06 (sig. non-normal) normality test p=0.508 normality test p=0.007 (sig. non-normal) normality test p=0.077 normality test p=0.167 normality test p=4.472E-05 (sig. non-normal) normality test p=0.037 (sig. non-normal) normality test p=0.015 (sig. non-normal) normality test p=2.007E-11 (sig. non-normal)
# 	At least one distribution is significantly non-normal.
# 	Non-parametric test. 0.2978 N.S.
# Pooled deviation 0.10060001200125426
# -------
# Rois in narrow_end [1, 2, 3, 4, 5, 6]
# Rois in wide_lumen [16, 17, 18, 19, 20, 21]
#     repeat 1) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.9957 N.S.
# Pooled deviation 0.10086360246390375
# -------
#     repeat 2) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.2401 N.S.
# Pooled deviation 0.10103803877518293
# -------
#     repeat 3) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.7520 N.S.
# Pooled deviation 0.09944692153249789
# -------
#     repeat 4) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.1149 N.S.
# Pooled deviation 0.10122666535540766
# -------
#     repeat 5) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.1766 N.S.
# Pooled deviation 0.09941395854683927
# -------
# Rois in wide_end [7, 8, 9]
# Rois in narrow_lumen [10, 11, 12, 13, 14, 15]
#     repeat 1) 25 < min_n1 (33), min_n2 (29) < 100,
# 	normality test p=0.030 (sig. non-normal) normality test p=0.002 (sig. non-normal) normality test p=0.007 (sig. non-normal) normality test p=2.590E-10 (sig. non-normal) normality test p=0.009 (sig. non-normal) normality test p=1.326E-08 (sig. non-normal) normality test p=0.002 (sig. non-normal) normality test p=0.006 (sig. non-normal) normality test p=0.001 (sig. non-normal)
# 	At least one distribution is significantly non-normal.
# 	Non-parametric test. 0.8372 N.S.
# Pooled deviation 0.10012712906396586
# -------
#     repeat 2) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.2408 N.S.
# Pooled deviation 0.1028921257539542
# -------
#     repeat 3) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.6365 N.S.
# Pooled deviation 0.10023178967510386
# -------
#     repeat 4) 25 < min_n1 (36), min_n2 (30) < 100,
# 	normality test p=0.136 normality test p=3.645E-05 (sig. non-normal) normality test p=0.309 normality test p=0.006 (sig. non-normal) normality test p=0.152 normality test p=1.376E-05 (sig. non-normal) normality test p=0.079 normality test p=0.370 normality test p=9.611E-07 (sig. non-normal)
# 	At least one distribution is significantly non-normal.
# 	Non-parametric test. 0.4310 N.S.
# Pooled deviation 0.09775025257803631
# -------
#     repeat 5) 25 < min_n1 (28), min_n2 (30) < 100,
# 	normality test p=0.232 normality test p=2.456E-16 (sig. non-normal) normality test p=1.344E-07 (sig. non-normal) normality test p=0.077 normality test p=0.167 normality test p=4.472E-05 (sig. non-normal) normality test p=0.037 (sig. non-normal) normality test p=0.015 (sig. non-normal) normality test p=2.007E-11 (sig. non-normal)
# 	At least one distribution is significantly non-normal.
# 	Non-parametric test. 0.8654 N.S.
# Pooled deviation 0.10149142572063073
# -------
# Rois in wide_end [7, 8, 9]
# Rois in wide_lumen [16, 17, 18, 19, 20, 21]
#     repeat 1) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.9919 N.S.
# Pooled deviation 0.10155568626894614
# -------
#     repeat 2) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.0436 Significant differences. Reject H0
# Pooled deviation 0.10202073633145334
# -------
#     repeat 3) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.7592 N.S.
# Pooled deviation 0.10233147181866038
# -------
#     repeat 4) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.4422 N.S.
# Pooled deviation 0.09757264001391243
# -------
#     repeat 5) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.4762 N.S.
# Pooled deviation 0.099521560667693
# -------
# Rois in narrow_lumen [10, 11, 12, 13, 14, 15]
# Rois in wide_lumen [16, 17, 18, 19, 20, 21]
#     repeat 1) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.9849 N.S.
# Pooled deviation 0.099199468872025
# -------
#     repeat 2) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.2959 N.S.
# Pooled deviation 0.10035390827621703
# -------
#     repeat 3) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.7352 N.S.
# Pooled deviation 0.09909758296217984
# -------
#     repeat 4) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.7331 N.S.
# Pooled deviation 0.09581954353998418
# -------
#     repeat 5) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.8533 N.S.
# Pooled deviation 0.09953675772278617
# -------

# %%
def differences_between_rois_in_different_class_same_region_pooled(section):
    """
    Test for significant differences between distinct ROI classes by using all the elements in each class
    In order to test each class against the others, we need to use combinations of the classes
    """
    print('=='*20, '\n','ROIs in different class in', section)
    for roi_class_1, roi_class_2 in [p for p in combinations([t[0] for t in classes2['ordering']], 2)]:
        print('Rois in', roi_class_1, [roi for roi in classes2[section][roi_class_1]])
        print('Rois in', roi_class_2, [roi for roi in classes2[section][roi_class_2]])
        
        #for rep in range(5):
        dpr1, dpr2 = [], []
        lengths1, lengths2 = [], []
        #print('    repeat',rep+1, end=') ')
        for i_roi in classes2[section][roi_class_1]:
            d1 = v2b_data.query(f"section=='{section}' & replicate in [0,1,2,3,4] & roi=={i_roi-1}")['radius_um']
            lengths1.append((i_roi, len(d1)))
            dpr1.append(d1)
        for i_roi in classes2[section][roi_class_2]:
            d2 = v2b_data.query(f"section=='{section}' & replicate in [0,1,2,3,4] & roi=={i_roi-1}")['radius_um']
            lengths2.append((i_roi, len(d2)))
            dpr2.append(d2)

        # all the test must be done to both lists of data
        min_n1 = min([len(d) for d in dpr1])
        min_n2 = min([len(d) for d in dpr2])
        # samples with less than 3 data points cannot be tested
        if min_n1 < 3:
            print('min_n1 < 3, Attempting testing a subset of the data.', end=' ')
            original_dpr1 = dpr1
            dpr1 = [d for d in dpr1 if len(d)>3]
            print('Elements skipped:', [pair for pair in lengths1 if pair[1] < 3], end='\n\t      ')
            if len(dpr1) < 2:
                print('There are not sufficient data points for testing')
                break
            min_n1 = min([len(d) for d in dpr1])
        if min_n2 < 3:
            print('min_n2 < 3, Attempting testing a subset of the data.', end=' ')
            original_dpr2 = dpr2
            dpr2 = [d for d in dpr2 if len(d)>3]
            print('Elements skipped:', [pair for pair in lengths2 if pair[1] < 3], end='\n\t      ')
            if len(dpr2) < 2:
                print('There are not sufficient data points for testing')
                break
            min_n2 = min([len(d) for d in dpr2])

        # one way t-test assumes homoscedasticity, we must check the samples have the same variance
        parametric = False
        if min_n1 > 99 and min_n2 > 99:
            print(f'min_n1 ({min_n1}) > 100 and min_n2 ({min_n2}) > 99, Normality not highly important, skipping test', end=' ')
            # same variances?
            levene_stat, levene_p = sp_stats.levene(*dpr1, *dpr2)
            if levene_p > 0.05:
                parametric = True
                print('Fail to reject Homoscedasticity', end=' ')
            else:
                print('Significantly different variances.', end=' ')

        elif min_n1 > 25 and min_n2 > 25:
            print(f'25 < min_n1 ({min_n1}), min_n2 ({min_n2}) < 100,', end='\n\t')
            if min([test_normality(d) for d in dpr1 + dpr2]) < 0.05:
                print('\n\tAt least one distribution is significantly non-normal.', end=' ')
            else:
                print('\n\tDistributions not significantly different from normal', end=' ')
                # same variances?
                levene_stat, levene_p = sp_stats.levene(*dpr1, *dpr2)
                if levene_p > 0.05:
                    parametric = True
                    print('Fail to reject Homoscedasticity', end=' ')
                else:
                    print('Significantly different variances.', end=' ')
        else:
            print(f'3 < min_n ({min_n}) < 25,', end=' ')

        if parametric:
            res = sp_stats.f_oneway(*dpr1, *dpr2)
            print(f'\n\tParametric test. {res[1]:.4f}', end=' ')
        else:
            res = sp_stats.kruskal(*dpr1, *dpr2)
            print(f'\n\tNon-parametric test. {res[1]:.4f}', end=' ')
        print('N.S.' if res[1] > alpha else 'Significant differences. Reject H0')
        dprs = dpr1 + dpr2
        pooled_dev = np.sqrt(np.sum([(r.count()-1) * (r.mean()**2) for r in dprs]) / (np.sum([r.count() for r in dprs]) - len(dprs)))
        print('Pooled deviation', pooled_dev,'\n-------')
                
differences_between_rois_in_different_class_same_region_pooled('ampulla1')
differences_between_rois_in_different_class_same_region_pooled('isthmus')
# Out:
# ========================================
#  ROIs in different class in ampulla1
# Rois in narrow_end [1, 2, 3, 4, 5, 6]
# Rois in wide_end [7, 8, 9, 10, 11, 12]
# 3 < min_n (6) < 25,
# 	Non-parametric test. 0.4553 N.S.
# Pooled deviation 0.10100714042074604
# -------
# Rois in narrow_end [1, 2, 3, 4, 5, 6]
# Rois in narrow_lumen [13, 14, 15, 16, 17, 18]
# 3 < min_n (6) < 25,
# 	Non-parametric test. 0.9689 N.S.
# Pooled deviation 0.10171475249014589
# -------
# Rois in narrow_end [1, 2, 3, 4, 5, 6]
# Rois in wide_lumen [19, 20, 21, 22, 23, 24]
# min_n2 < 3, Attempting testing a subset of the data. Elements skipped: [(20, 2)]
# 	      3 < min_n (6) < 25,
# 	Non-parametric test. 0.7134 N.S.
# Pooled deviation 0.10216002289982638
# -------
# Rois in wide_end [7, 8, 9, 10, 11, 12]
# Rois in narrow_lumen [13, 14, 15, 16, 17, 18]
# 3 < min_n (6) < 25,
# 	Non-parametric test. 0.5769 N.S.
# Pooled deviation 0.10088754253383027
# -------
# Rois in wide_end [7, 8, 9, 10, 11, 12]
# Rois in wide_lumen [19, 20, 21, 22, 23, 24]
# min_n2 < 3, Attempting testing a subset of the data. Elements skipped: [(20, 2)]
# 	      3 < min_n (6) < 25,
# 	Non-parametric test. 0.2211 N.S.
# Pooled deviation 0.1009658163859207
# -------
# Rois in narrow_lumen [13, 14, 15, 16, 17, 18]
# Rois in wide_lumen [19, 20, 21, 22, 23, 24]
# min_n2 < 3, Attempting testing a subset of the data. Elements skipped: [(20, 2)]
# 	      3 < min_n (6) < 25,
# 	Non-parametric test. 0.8999 N.S.
# Pooled deviation 0.10258657513622416
# -------
# ========================================
#  ROIs in different class in isthmus
# Rois in narrow_end [1, 2, 3, 4, 5, 6]
# Rois in wide_end [7, 8, 9]
# min_n1 (324) > 100 and min_n2 (161) > 99, Normality not highly important, skipping test Fail to reject Homoscedasticity
# 	Parametric test. 0.7404 N.S.
# Pooled deviation 0.10135838204641316
# -------
# Rois in narrow_end [1, 2, 3, 4, 5, 6]
# Rois in narrow_lumen [10, 11, 12, 13, 14, 15]
# min_n1 (324) > 100 and min_n2 (141) > 99, Normality not highly important, skipping test Fail to reject Homoscedasticity
# 	Parametric test. 0.6638 N.S.
# Pooled deviation 0.1003213353657937
# -------
# Rois in narrow_end [1, 2, 3, 4, 5, 6]
# Rois in wide_lumen [16, 17, 18, 19, 20, 21]
# 25 < min_n1 (324), min_n2 (61) < 100,
# 	normality test p=2.868E-49 (sig. non-normal) normality test p=2.158E-61 (sig. non-normal) normality test p=5.494E-86 (sig. non-normal) normality test p=4.870E-48 (sig. non-normal) normality test p=4.892E-29 (sig. non-normal) normality test p=1.042E-17 (sig. non-normal) normality test p=3.431E-12 (sig. non-normal) normality test p=4.315E-06 (sig. non-normal) normality test p=0.168 normality test p=1.248E-07 (sig. non-normal) normality test p=9.428E-04 (sig. non-normal) normality test p=0.002 (sig. non-normal)
# 	At least one distribution is significantly non-normal.
# 	Non-parametric test. 0.2100 N.S.
# Pooled deviation 0.10029738292349931
# -------
# Rois in wide_end [7, 8, 9]
# Rois in narrow_lumen [10, 11, 12, 13, 14, 15]
# min_n1 (161) > 100 and min_n2 (141) > 99, Normality not highly important, skipping test Fail to reject Homoscedasticity
# 	Parametric test. 0.3438 N.S.
# Pooled deviation 0.10044277977769564
# -------
# Rois in wide_end [7, 8, 9]
# Rois in wide_lumen [16, 17, 18, 19, 20, 21]
# 25 < min_n1 (161), min_n2 (61) < 100,
# 	normality test p=8.509E-11 (sig. non-normal) normality test p=8.398E-50 (sig. non-normal) normality test p=6.825E-16 (sig. non-normal) normality test p=3.431E-12 (sig. non-normal) normality test p=4.315E-06 (sig. non-normal) normality test p=0.168 normality test p=1.248E-07 (sig. non-normal) normality test p=9.428E-04 (sig. non-normal) normality test p=0.002 (sig. non-normal)
# 	At least one distribution is significantly non-normal.
# 	Non-parametric test. 0.0510 N.S.
# Pooled deviation 0.10047606347273182
# -------
# Rois in narrow_lumen [10, 11, 12, 13, 14, 15]
# Rois in wide_lumen [16, 17, 18, 19, 20, 21]
# 25 < min_n1 (141), min_n2 (61) < 100,
# 	normality test p=1.709E-40 (sig. non-normal) normality test p=8.324E-15 (sig. non-normal) normality test p=9.010E-83 (sig. non-normal) normality test p=4.736E-21 (sig. non-normal) normality test p=2.313E-10 (sig. non-normal) normality test p=6.627E-41 (sig. non-normal) normality test p=3.431E-12 (sig. non-normal) normality test p=4.315E-06 (sig. non-normal) normality test p=0.168 normality test p=1.248E-07 (sig. non-normal) normality test p=9.428E-04 (sig. non-normal) normality test p=0.002 (sig. non-normal)
# 	At least one distribution is significantly non-normal.
# 	Non-parametric test. 0.4763 N.S.
# Pooled deviation 0.09869572999346692
# -------

# %% [markdown]
# # Same class - different region

# %%
# rois in different class
def differences_between_rois_in_same_class_different_region():
    """
    Test for significant differences between distinct ROI classes by using all the elements in each class
    In order to test each class against the others, we need to use combinations of the classes
    """
    sections = ['isthmus', 'ampulla1']
    print('=='*20, '\n','ROIs in different class in', sections)
    for class_name, class_colour in classes2['ordering']:
        rois_class_1 = [roi for roi in classes2[sections[0]][class_name]]
        rois_class_2 = [roi for roi in classes2[sections[1]][class_name]]
        print('Rois in', class_name, rois_class_1)
        print('Rois in', class_name, rois_class_2)

        for rep in range(5):
            dpr1, dpr2 = [], []
            lengths1, lengths2 = [], []
            print('    repeat',rep+1, end=') ')
            for i_roi in rois_class_1:
                d1 = v2b_data.query(f"section=='{sections[0]}' & replicate=={rep} & roi=={i_roi-1}")['radius_um']
                lengths1.append((i_roi, len(d1)))
                dpr1.append(d1)
            for i_roi in rois_class_2:
                d2 = v2b_data.query(f"section=='{sections[1]}' & replicate=={rep} & roi=={i_roi-1}")['radius_um']
                lengths2.append((i_roi, len(d2)))
                dpr2.append(d2)

            # all the test must be done to both lists of data
            min_n1 = min([len(d) for d in dpr1])
            min_n2 = min([len(d) for d in dpr2])
            # samples with less than 3 data points cannot be tested
            if min_n1 < 3:
                print('min_n1 < 3, Attempting testing a subset of the data.', end=' ')
                original_dpr1 = dpr1
                dpr1 = [d for d in dpr1 if len(d)>3]
                print('Elements skipped:', [pair for pair in lengths1 if pair[1] < 3], end='\n\t      ')
                if len(dpr1) < 2:
                    print('There are not sufficient data points for testing')
                    break
                min_n1 = min([len(d) for d in dpr1])
            if min_n2 < 3:
                print('min_n2 < 3, Attempting testing a subset of the data.', end=' ')
                original_dpr2 = dpr2
                dpr2 = [d for d in dpr2 if len(d)>3]
                print('Elements skipped:', [pair for pair in lengths2 if pair[1] < 3], end='\n\t      ')
                if len(dpr2) < 2:
                    print('There are not sufficient data points for testing')
                    break
                min_n2 = min([len(d) for d in dpr2])

            # one way t-test assumes homoscedasticity, we must check the samples have the same variance
            parametric = False
            if min_n1 > 99 and min_n2 > 99:
                print(f'min_n1 ({min_n1}) > 100 and min_n2 ({min_n2}) > 99, Normality not highly important, skipping test', end=' ')
                # same variances?
                levene_stat, levene_p = sp_stats.levene(*dpr1, *dpr2)
                if levene_p > 0.05:
                    parametric = True
                    print('Fail to reject Homoscedasticity', end=' ')
                else:
                    print('Significantly different variances.', end=' ')
                    
            elif min_n1 > 25 and min_n2 > 25:
                print(f'25 < min_n1 ({min_n1}), min_n2 ({min_n2}) < 100,', end='\n\t')
                if min([test_normality(d) for d in dpr1 + dpr2]) < 0.05:
                    print('\n\tAt least one distribution is significantly non-normal.', end=' ')
                else:
                    print('\n\tDistributions not significantly different from normal', end=' ')
                    # same variances?
                    levene_stat, levene_p = sp_stats.levene(*dpr1, *dpr2)
                    if levene_p > 0.05:
                        parametric = True
                        print('Fail to reject Homoscedasticity', end=' ')
                    else:
                        print('Significantly different variances.', end=' ')
            else:
                print(f'3 < min_n ({min_n}) < 25,', end=' ')
            
            if parametric:
                res = sp_stats.f_oneway(*dpr1, *dpr2)
                print(f'\n\tParametric test. {res[1]:.4f}', end=' ')
            else:
                res = sp_stats.kruskal(*dpr1, *dpr2)
                print(f'\n\tNon-parametric test. {res[1]:.4f}', end=' ')
            print('N.S.' if res[1] > alpha else 'Significant differences. Reject H0')
            
            dprs = dpr1 + dpr2
            pooled_dev = np.sqrt(np.sum([(r.count()-1) * (r.mean()**2) for r in dprs]) / (np.sum([r.count() for r in dprs]) - len(dprs)))
            print('Pooled deviation', pooled_dev,'\n-------')
                
differences_between_rois_in_same_class_different_region()
# Out:
# ========================================
#  ROIs in different class in ['isthmus', 'ampulla1']
# Rois in narrow_end [1, 2, 3, 4, 5, 6]
# Rois in narrow_end [1, 2, 3, 4, 5, 6]
#     repeat 1) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.5844 N.S.
# Pooled deviation 0.10165063601091319
# -------
#     repeat 2) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.2672 N.S.
# Pooled deviation 0.10099811037586647
# -------
#     repeat 3) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.6171 N.S.
# Pooled deviation 0.09899748154500136
# -------
#     repeat 4) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.2487 N.S.
# Pooled deviation 0.10263574499422072
# -------
#     repeat 5) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.0663 N.S.
# Pooled deviation 0.10145140638650826
# -------
# Rois in wide_end [7, 8, 9]
# Rois in wide_end [7, 8, 9, 10, 11, 12]
#     repeat 1) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.4726 N.S.
# Pooled deviation 0.10224048193164795
# -------
#     repeat 2) min_n2 < 3, Attempting testing a subset of the data. Elements skipped: [(8, 2)]
# 	      3 < min_n (6) < 25,
# 	Non-parametric test. 0.0064 Significant differences. Reject H0
# Pooled deviation 0.10467874726465823
# -------
#     repeat 3) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.6468 N.S.
# Pooled deviation 0.10441193467510382
# -------
#     repeat 4) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.1864 N.S.
# Pooled deviation 0.09799099042629328
# -------
#     repeat 5) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.5078 N.S.
# Pooled deviation 0.10227347413075463
# -------
# Rois in narrow_lumen [10, 11, 12, 13, 14, 15]
# Rois in narrow_lumen [13, 14, 15, 16, 17, 18]
#     repeat 1) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.9550 N.S.
# Pooled deviation 0.09883773004026623
# -------
#     repeat 2) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.2032 N.S.
# Pooled deviation 0.10068542524107325
# -------
#     repeat 3) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.5565 N.S.
# Pooled deviation 0.09867905399047726
# -------
#     repeat 4) min_n2 < 3, Attempting testing a subset of the data. Elements skipped: [(18, 2)]
# 	      3 < min_n (6) < 25,
# 	Non-parametric test. 0.1019 N.S.
# Pooled deviation 0.0987904567793463
# -------
#     repeat 5) 3 < min_n (6) < 25,
# 	Non-parametric test. 0.9106 N.S.
# Pooled deviation 0.10169898809742477
# -------
# Rois in wide_lumen [16, 17, 18, 19, 20, 21]
# Rois in wide_lumen [19, 20, 21, 22, 23, 24]
#     repeat 1) min_n2 < 3, Attempting testing a subset of the data. Elements skipped: [(20, 1), (21, 1), (22, 2), (23, 1), (24, 1)]
# 	      There are not sufficient data points for testing

# %%
# rois in different class
def differences_between_rois_in_same_class_different_region_pooled():
    """
    Test for significant differences between distinct ROI classes by using all the elements in each class
    In order to test each class against the others, we need to use combinations of the classes
    """
    sections = ['isthmus', 'ampulla1']
    print('=='*20, '\n','ROIs in different class in', sections)
    for class_name, class_colour in classes2['ordering']:
        rois_class_1 = [roi for roi in classes2[sections[0]][class_name]]
        rois_class_2 = [roi for roi in classes2[sections[1]][class_name]]
        print('Rois in', class_name, rois_class_1)
        print('Rois in', class_name, rois_class_2)

        #for rep in range(5):
        dpr1, dpr2 = [], []
        lengths1, lengths2 = [], []
        #print('    repeat',rep+1, end=') ')
        for i_roi in rois_class_1:
            d1 = v2b_data.query(f"section=='{sections[0]}' & replicate in [0,1,2,3,4] & roi=={i_roi-1}")['radius_um']
            lengths1.append((i_roi, len(d1)))
            dpr1.append(d1)
        for i_roi in rois_class_2:
            d2 = v2b_data.query(f"section=='{sections[1]}' & replicate in [0,1,2,3,4] & roi=={i_roi-1}")['radius_um']
            lengths2.append((i_roi, len(d2)))
            dpr2.append(d2)

        # all the test must be done to both lists of data
        min_n1 = min([len(d) for d in dpr1])
        min_n2 = min([len(d) for d in dpr2])
        # samples with less than 3 data points cannot be tested
        if min_n1 < 3:
            print('min_n1 < 3, Attempting testing a subset of the data.', end=' ')
            original_dpr1 = dpr1
            dpr1 = [d for d in dpr1 if len(d)>3]
            print('Elements skipped:', [pair for pair in lengths1 if pair[1] < 3], end='\n\t      ')
            if len(dpr1) < 2:
                print('There are not sufficient data points for testing')
                break
            min_n1 = min([len(d) for d in dpr1])
        if min_n2 < 3:
            print('min_n2 < 3, Attempting testing a subset of the data.', end=' ')
            original_dpr2 = dpr2
            dpr2 = [d for d in dpr2 if len(d)>3]
            print('Elements skipped:', [pair for pair in lengths2 if pair[1] < 3], end='\n\t      ')
            if len(dpr2) < 2:
                print('There are not sufficient data points for testing')
                break
            min_n2 = min([len(d) for d in dpr2])

        # one way t-test assumes homoscedasticity, we must check the samples have the same variance
        parametric = False
        if min_n1 > 99 and min_n2 > 99:
            print(f'min_n1 ({min_n1}) > 100 and min_n2 ({min_n2}) > 99, Normality not highly important, skipping test', end=' ')
            # same variances?
            levene_stat, levene_p = sp_stats.levene(*dpr1, *dpr2)
            if levene_p > 0.05:
                parametric = True
                print('Fail to reject Homoscedasticity', end=' ')
            else:
                print('Significantly different variances.', end=' ')

        elif min_n1 > 25 and min_n2 > 25:
            print(f'25 < min_n1 ({min_n1}), min_n2 ({min_n2}) < 100,', end='\n\t')
            if min([test_normality(d) for d in dpr1 + dpr2]) < 0.05:
                print('\n\tAt least one distribution is significantly non-normal.', end=' ')
            else:
                print('\n\tDistributions not significantly different from normal', end=' ')
                # same variances?
                levene_stat, levene_p = sp_stats.levene(*dpr1, *dpr2)
                if levene_p > 0.05:
                    parametric = True
                    print('Fail to reject Homoscedasticity', end=' ')
                else:
                    print('Significantly different variances.', end=' ')
        else:
            print(f'3 < min_n ({min_n}) < 25,', end=' ')

        if parametric:
            res = sp_stats.f_oneway(*dpr1, *dpr2)
            print(f'\n\tParametric test. {res[1]:.4f}', end=' ')
        else:
            res = sp_stats.kruskal(*dpr1, *dpr2)
            print(f'\n\tNon-parametric test. {res[1]:.4f}', end=' ')
        print('N.S.' if res[1] > alpha else 'Significant differences. Reject H0')
        
        dprs = dpr1 + dpr2
        pooled_dev = np.sqrt(np.sum([(r.count()-1) * (r.mean()**2) for r in dprs]) / (np.sum([r.count() for r in dprs]) - len(dprs)))
        print('Pooled deviation', pooled_dev,'\n-------')
                
differences_between_rois_in_same_class_different_region_pooled()
# Out:
# ========================================
#  ROIs in different class in ['isthmus', 'ampulla1']
# Rois in narrow_end [1, 2, 3, 4, 5, 6]
# Rois in narrow_end [1, 2, 3, 4, 5, 6]
# 25 < min_n1 (324), min_n2 (55) < 100,
# 	normality test p=2.868E-49 (sig. non-normal) normality test p=2.158E-61 (sig. non-normal) normality test p=5.494E-86 (sig. non-normal) normality test p=4.870E-48 (sig. non-normal) normality test p=4.892E-29 (sig. non-normal) normality test p=1.042E-17 (sig. non-normal) normality test p=2.872E-14 (sig. non-normal) normality test p=1.705E-06 (sig. non-normal) normality test p=1.024E-04 (sig. non-normal) normality test p=0.010 (sig. non-normal) normality test p=2.063E-04 (sig. non-normal) normality test p=0.005 (sig. non-normal)
# 	At least one distribution is significantly non-normal.
# 	Non-parametric test. 0.8833 N.S.
# Pooled deviation 0.10106137751956412
# -------
# Rois in wide_end [7, 8, 9]
# Rois in wide_end [7, 8, 9, 10, 11, 12]
# 3 < min_n (6) < 25,
# 	Non-parametric test. 0.2587 N.S.
# Pooled deviation 0.10201569047828363
# -------
# Rois in narrow_lumen [10, 11, 12, 13, 14, 15]
# Rois in narrow_lumen [13, 14, 15, 16, 17, 18]
# 3 < min_n (6) < 25,
# 	Non-parametric test. 0.8911 N.S.
# Pooled deviation 0.09967576047523397
# -------
# Rois in wide_lumen [16, 17, 18, 19, 20, 21]
# Rois in wide_lumen [19, 20, 21, 22, 23, 24]
# min_n2 < 3, Attempting testing a subset of the data. Elements skipped: [(20, 2)]
# 	      3 < min_n (6) < 25,
# 	Non-parametric test. 0.2260 N.S.
# Pooled deviation 0.09791528122523965
# -------

# %% [markdown]
# # Different class - different region

# %%
# rois in different class
def differences_between_rois_in_different_class_different_region():
    """
    Test for significant differences between same ROI classes in distinct region by using all the elements in each class
    In order to test each class against the others
    """
    sections = ['isthmus', 'ampulla1']
    print('=='*20, '\n','ROIs in different class in sections', sections)
    
    for roi_class1, roi_class2 in [p for p in combinations([t[0] for t in classes2['ordering']], 2)]:
        # fetch all the ROis in class x in the isthmus
        # fetch all the ROis in class x in the ampulla1
        # compare ROIs in both sectinons ysung 
        rois_class1 = [roi for roi in classes2[sections[0]][roi_class1]]
        rois_class2 = [roi for roi in classes2[sections[1]][roi_class2]]
        print('Rois in', roi_class1, rois_class1)
        print('Rois in', roi_class2, rois_class2)
        
        for rep in range(5):
            dpr1, dpr2 = [], []
            lengths1, lengths2 = [], []
            print('    repeat',rep+1, end=') ')
            for i_roi in rois_class1:
                d1 = v2b_data.query(f"section=='{sections[0]}' & replicate=={rep} & roi=={i_roi-1}")['radius_um']
                lengths1.append((i_roi, len(d1)))
                dpr1.append(d1)
            for i_roi in rois_class2:
                d2 = v2b_data.query(f"section=='{sections[1]}' & replicate=={rep} & roi=={i_roi-1}")['radius_um']
                lengths2.append((i_roi, len(d2)))
                dpr2.append(d2)

            # all the test must be done to both lists of data
            min_n1 = min([len(d) for d in dpr1])
            min_n2 = min([len(d) for d in dpr2])
            # samples with less than 3 data points cannot be tested
            if min_n1 < 3:
                print('min_n1 < 3, Attempting testing a subset of the data.', end=' ')
                original_dpr1 = dpr1
                dpr1 = [d for d in dpr1 if len(d)>3]
                print('Elements skipped:', [pair for pair in lengths1 if pair[1] < 3], end='\n\t      ')
                if len(dpr1) < 2:
                    print('There are not sufficient data points for testing')
                    break
                min_n1 = min([len(d) for d in dpr1])
            if min_n2 < 3:
                print('min_n2 < 3, Attempting testing a subset of the data.', end=' ')
                original_dpr2 = dpr2
                dpr2 = [d for d in dpr2 if len(d)>3]
                print('Elements skipped:', [pair for pair in lengths2 if pair[1] < 3], end='\n\t      ')
                if len(dpr2) < 2:
                    print('There are not sufficient data points for testing')
                    break
                min_n2 = min([len(d) for d in dpr2])

            # one way t-test assumes homoscedasticity, we must check the samples have the same variance
            parametric = False
            if min_n1 > 99 and min_n2 > 99:
                print(f'min_n1 ({min_n1}) > 100 and min_n2 ({min_n2}) > 99, Normality not highly important, skipping test', end=' ')
                # same variances?
                levene_stat, levene_p = sp_stats.levene(*dpr1, *dpr2)
                if levene_p > 0.05:
                    parametric = True
                    print('Fail to reject Homoscedasticity', end=' ')
                else:
                    print('Significantly different variances.', end=' ')
                    
            elif min_n1 > 25 and min_n2 > 25:
                print(f'25 < min_n1 ({min_n1}), min_n2 ({min_n2}) < 100,', end='\n\t')
                if min([test_normality(d) for d in dpr1 + dpr2]) < 0.05:
                    print('\n\tAt least one distribution is significantly non-normal.', end=' ')
                else:
                    print('\n\tDistributions not significantly different from normal', end=' ')
                    # same variances?
                    levene_stat, levene_p = sp_stats.levene(*dpr1, *dpr2)
                    if levene_p > 0.05:
                        parametric = True
                        print('Fail to reject Homoscedasticity', end=' ')
                    else:
                        print('Significantly different variances.', end=' ')
            else:
                print(f'3 < min_n ({min_n}) < 25,', end=' ')
            
            if parametric:
                res = sp_stats.f_oneway(*dpr1, *dpr2)
                print('\n\tParametric test.\n\t', res[1], end=' ')
            else:
                res = sp_stats.kruskal(*dpr1, *dpr2)
                print('\n\tNon-parametric test.\n\t', res[1], end=' ')
            print('N.S.' if res[1] > alpha else 'Significant differences. Reject H0')
            
            dprs = dpr1 + dpr2
            pooled_dev = np.sqrt(np.sum([(r.count()-1) * (r.mean()**2) for r in dprs]) / (np.sum([r.count() for r in dprs]) - len(dprs)))
            print('Pooled deviation', pooled_dev,'\n-------')
                
differences_between_rois_in_different_class_different_region()
# Out:
# ========================================
#  ROIs in different class in sections ['isthmus', 'ampulla1']
# Rois in narrow_end [1, 2, 3, 4, 5, 6]
# Rois in wide_end [7, 8, 9, 10, 11, 12]
#     repeat 1) 3 < min_n (6) < 25,
# 	Non-parametric test.
# 	 0.6050700273474181 N.S.
# Pooled deviation 0.10106819063342332
# -------
#     repeat 2) min_n2 < 3, Attempting testing a subset of the data. Elements skipped: [(8, 2)]
# 	      3 < min_n (6) < 25,
# 	Non-parametric test.
# 	 0.04980437824039922 Significant differences. Reject H0
# Pooled deviation 0.10186359143744017
# -------
#     repeat 3) 3 < min_n (6) < 25,
# 	Non-parametric test.
# 	 0.5750102564597789 N.S.
# Pooled deviation 0.09968846334659794
# -------
#     repeat 4) 3 < min_n (6) < 25,
# 	Non-parametric test.
# 	 0.0631075316539361 N.S.
# Pooled deviation 0.10181095404872688
# -------
#     repeat 5) 3 < min_n (6) < 25,
# 	Non-parametric test.
# 	 0.12203668216076992 N.S.
# Pooled deviation 0.10045778602538755
# -------
# Rois in narrow_end [1, 2, 3, 4, 5, 6]
# Rois in narrow_lumen [13, 14, 15, 16, 17, 18]
#     repeat 1) 3 < min_n (6) < 25,
# 	Non-parametric test.
# 	 0.9554452207035775 N.S.
# Pooled deviation 0.10073864891252927
# -------
#     repeat 2) 3 < min_n (6) < 25,
# 	Non-parametric test.
# 	 0.16501902650644257 N.S.
# Pooled deviation 0.10129386956548428
# -------
#     repeat 3) 3 < min_n (6) < 25,
# 	Non-parametric test.
# 	 0.5165987649295903 N.S.
# Pooled deviation 0.09921774182620727
# -------
#     repeat 4) min_n2 < 3, Attempting testing a subset of the data. Elements skipped: [(18, 2)]
# 	      3 < min_n (6) < 25,
# 	Non-parametric test.
# 	 0.11563187694964305 N.S.
# Pooled deviation 0.10329044142090928
# -------
#     repeat 5) 3 < min_n (6) < 25,
# 	Non-parametric test.
# 	 0.14481435537805593 N.S.
# Pooled deviation 0.10080914214767367
# -------
# Rois in narrow_end [1, 2, 3, 4, 5, 6]
# Rois in wide_lumen [19, 20, 21, 22, 23, 24]
#     repeat 1) min_n2 < 3, Attempting testing a subset of the data. Elements skipped: [(20, 1), (21, 1), (22, 2), (23, 1), (24, 1)]
# 	      There are not sufficient data points for testing
# Rois in wide_end [7, 8, 9]
# Rois in narrow_lumen [13, 14, 15, 16, 17, 18]
#     repeat 1) 3 < min_n (6) < 25,
# 	Non-parametric test.
# 	 0.905461494056782 N.S.
# Pooled deviation 0.10135822062174167
# -------
#     repeat 2) 3 < min_n (6) < 25,
# 	Non-parametric test.
# 	 0.02168384298928802 Significant differences. Reject H0
# Pooled deviation 0.1028823685977621
# -------
#     repeat 3) 3 < min_n (6) < 25,
# 	Non-parametric test.
# 	 0.5079656562264847 N.S.
# Pooled deviation 0.10275190769724617
# -------
#     repeat 4) min_n2 < 3, Attempting testing a subset of the data. Elements skipped: [(18, 2)]
# 	      3 < min_n (6) < 25,
# 	Non-parametric test.
# 	 0.10956328917341418 N.S.
# Pooled deviation 0.10276735378592743
# -------
#     repeat 5) 3 < min_n (6) < 25,
# 	Non-parametric test.
# 	 0.6400528159618797 N.S.
# Pooled deviation 0.10292789690896585
# -------
# Rois in wide_end [7, 8, 9]
# Rois in wide_lumen [19, 20, 21, 22, 23, 24]
#     repeat 1) min_n2 < 3, Attempting testing a subset of the data. Elements skipped: [(20, 1), (21, 1), (22, 2), (23, 1), (24, 1)]
# 	      There are not sufficient data points for testing
# Rois in narrow_lumen [10, 11, 12, 13, 14, 15]
# Rois in wide_lumen [19, 20, 21, 22, 23, 24]
#     repeat 1) min_n2 < 3, Attempting testing a subset of the data. Elements skipped: [(20, 1), (21, 1), (22, 2), (23, 1), (24, 1)]
# 	      There are not sufficient data points for testing

# %%
# rois in different class
def differences_between_rois_in_different_class_different_region_pooled():
    """
    Test for significant differences between same ROI classes in distinct region by using all the elements in each class
    In order to test each class against the others
    """
    sections = ['isthmus', 'ampulla1']
    print('=='*20, '\n','ROIs in different class in sections', sections)
    
    for roi_class1, roi_class2 in [p for p in combinations([t[0] for t in classes2['ordering']], 2)]:
        # fetch all the ROis in class x in the isthmus
        # fetch all the ROis in class x in the ampulla1
        # compare ROIs in both sectinons ysung 
        rois_class1 = [roi for roi in classes2[sections[0]][roi_class1]]
        rois_class2 = [roi for roi in classes2[sections[1]][roi_class2]]
        print('Rois in', roi_class1, rois_class1)
        print('Rois in', roi_class2, rois_class2)
        
        #for rep in range(5):
        dpr1, dpr2 = [], []
        lengths1, lengths2 = [], []
        #print('    repeat',rep+1, end=') ')
        for i_roi in rois_class1:
            d1 = v2b_data.query(f"section=='{sections[0]}' & replicate in [0,1,2,3,4] & roi=={i_roi-1}")['radius_um']
            lengths1.append((i_roi, len(d1)))
            dpr1.append(d1)
        for i_roi in rois_class2:
            d2 = v2b_data.query(f"section=='{sections[1]}' & replicate in [0,1,2,3,4] & roi=={i_roi-1}")['radius_um']
            lengths2.append((i_roi, len(d2)))
            dpr2.append(d2)

        # all the test must be done to both lists of data
        min_n1 = min([len(d) for d in dpr1])
        min_n2 = min([len(d) for d in dpr2])
        # samples with less than 3 data points cannot be tested
        if min_n1 < 3:
            print('min_n1 < 3, Attempting testing a subset of the data.', end=' ')
            original_dpr1 = dpr1
            dpr1 = [d for d in dpr1 if len(d)>3]
            print('Elements skipped:', [pair for pair in lengths1 if pair[1] < 3], end='\n\t      ')
            if len(dpr1) < 2:
                print('There are not sufficient data points for testing')
                break
            min_n1 = min([len(d) for d in dpr1])
        if min_n2 < 3:
            print('min_n2 < 3, Attempting testing a subset of the data.', end=' ')
            original_dpr2 = dpr2
            dpr2 = [d for d in dpr2 if len(d)>3]
            print('Elements skipped:', [pair for pair in lengths2 if pair[1] < 3], end='\n\t      ')
            if len(dpr2) < 2:
                print('There are not sufficient data points for testing')
                break
            min_n2 = min([len(d) for d in dpr2])

        # one way t-test assumes homoscedasticity, we must check the samples have the same variance
        parametric = False
        if min_n1 > 99 and min_n2 > 99:
            print(f'min_n1 ({min_n1}) > 100 and min_n2 ({min_n2}) > 99, Normality not highly important, skipping test', end=' ')
            # same variances?
            levene_stat, levene_p = sp_stats.levene(*dpr1, *dpr2)
            if levene_p > 0.05:
                parametric = True
                print('Fail to reject Homoscedasticity', end=' ')
            else:
                print('Significantly different variances.', end=' ')

        elif min_n1 > 25 and min_n2 > 25:
            print(f'25 < min_n1 ({min_n1}), min_n2 ({min_n2}) < 100,', end='\n\t')
            if min([test_normality(d) for d in dpr1 + dpr2]) < 0.05:
                print('\n\tAt least one distribution is significantly non-normal.', end=' ')
            else:
                print('\n\tDistributions not significantly different from normal', end=' ')
                # same variances?
                levene_stat, levene_p = sp_stats.levene(*dpr1, *dpr2)
                if levene_p > 0.05:
                    parametric = True
                    print('Fail to reject Homoscedasticity', end=' ')
                else:
                    print('Significantly different variances.', end=' ')
        else:
            print(f'3 < min_n ({min_n}) < 25,', end=' ')

        if parametric:
            res = sp_stats.f_oneway(*dpr1, *dpr2)
            print('\n\tParametric test.\n\t', res[1], end=' ')
        else:
            res = sp_stats.kruskal(*dpr1, *dpr2)
            print('\n\tNon-parametric test.\n\t', res[1], end=' ')
        print('N.S.' if res[1] > alpha else 'Significant differences. Reject H0')
        
        dprs = dpr1 + dpr2
        pooled_dev = np.sqrt(np.sum([(r.count()-1) * (r.mean()**2) for r in dprs]) / (np.sum([r.count() for r in dprs]) - len(dprs)))
        print('Pooled deviation', pooled_dev,'\n-------')
differences_between_rois_in_different_class_different_region_pooled()
# Out:
# ========================================
#  ROIs in different class in sections ['isthmus', 'ampulla1']
# Rois in narrow_end [1, 2, 3, 4, 5, 6]
# Rois in wide_end [7, 8, 9, 10, 11, 12]
# 3 < min_n (6) < 25,
# 	Non-parametric test.
# 	 0.4545985190003018 N.S.
# Pooled deviation 0.10084631372962345
# -------
# Rois in narrow_end [1, 2, 3, 4, 5, 6]
# Rois in narrow_lumen [13, 14, 15, 16, 17, 18]
# 3 < min_n (6) < 25,
# 	Non-parametric test.
# 	 0.9612330782875278 N.S.
# Pooled deviation 0.10104445811582592
# -------
# Rois in narrow_end [1, 2, 3, 4, 5, 6]
# Rois in wide_lumen [19, 20, 21, 22, 23, 24]
# min_n2 < 3, Attempting testing a subset of the data. Elements skipped: [(20, 2)]
# 	      3 < min_n (6) < 25,
# 	Non-parametric test.
# 	 0.6940603588611964 N.S.
# Pooled deviation 0.10106680383416455
# -------
# Rois in wide_end [7, 8, 9]
# Rois in narrow_lumen [13, 14, 15, 16, 17, 18]
# 3 < min_n (6) < 25,
# 	Non-parametric test.
# 	 0.9705544365321911 N.S.
# Pooled deviation 0.10239858946481938
# -------
# Rois in wide_end [7, 8, 9]
# Rois in wide_lumen [19, 20, 21, 22, 23, 24]
# min_n2 < 3, Attempting testing a subset of the data. Elements skipped: [(20, 2)]
# 	      3 < min_n (6) < 25,
# 	Non-parametric test.
# 	 0.668025226817387 N.S.
# Pooled deviation 0.10286294067612374
# -------
# Rois in narrow_lumen [10, 11, 12, 13, 14, 15]
# Rois in wide_lumen [19, 20, 21, 22, 23, 24]
# min_n2 < 3, Attempting testing a subset of the data. Elements skipped: [(20, 2)]
# 	      3 < min_n (6) < 25,
# 	Non-parametric test.
# 	 0.6181074767625465 N.S.
# Pooled deviation 0.09948628913894861
# -------

# %% [markdown]
# # 1-way ANOVA
# Steps
# 1. Find the mean for each of the groups.
# 1. Find the overall mean (the mean of the groups combined).
#
# 1. Find the Between Group Variation (**Treatments**): the deviation of each Group Mean from the Overall Mean. It is the variability due to interaction between the groups. AKA: Sum of Squares Between ($SS_B, SS_{Between}$), Sum of Squares of the Model ($SS_{Model}$), Sum of Squares Treatments ($SS_{Treatment}$)
# $$
# \begin{equation*}
# \mathbf{SS_{B}} = \frac{\sum \left( \sum \left( k_i \right) ^2 \right)}{n} - \frac{T^2}{N}
# \end{equation*}
# $$
#
# 1. Find the Within Group Variation (**Error**): the total deviation of each member’s score from the Group Mean. The variability in the data due to differences within people. AKA: Sum of Squares Within ($SS_{W}, SS_{Within}$), Sum of Squares Error ($SS_{Error}$, $SS_{E}$) or Sum of Squares Residual ($SS_{Residual}$)
# $$
# \mathbf{SS_{W}} = \sum{Y^2} - \frac{\sum \left( \sum \left( a_i \right)^2 \right)}{n}
# $$
#
# 1. Find the F statistic: the ratio of Between Group Variation to Within Group Variation.
# $$
# \mathbf{F} = \frac{MS_{B}}{MS_{W}} \text{ or } \mathbf{F} = \frac{MS_{Treatment}}{MS_{Error}} \text{ or } \mathbf{F} = \frac{\text{expained variance}}{\text{unexplained variance}} \text{ or } \mathbf{F} = \frac{\text{between-group variability}}{\text{within-group variability}}
# $$
# where,
# $$
# \begin{align}
# \mathbf{MS_{B}}=\frac{SS_{B}}{DF_{B}}, \mathbf{DF_{B}}=K-1 && \begin{cases} K & \text{number of groups (factors)}\end{cases}
# \end{align}
# $$
# and
# $$
# \begin{align}
# \mathbf{MS_{W}}=\frac{SS_{W}}{DF_{W}}, \mathbf{DF_{W}}=k(n-1) && \begin{cases} k & \text{level of factor} \\  n & \text{observ in group} \end{cases}
# \end{align}
# $$
# Here, $MS_{Error}$ or $MS_{W}$ is the estimate of variance corresponding to $o^2$ of the model.
#
# [source](https://jooskorstanje.com/1_Way_ANOVA_Pizza_Delivery.html), [compliment](https://www.marsja.se/four-ways-to-conduct-one-way-anovas-using-python/#_ANOVA_in_Python_using_SciPy)

# %%
A = [12.6, 12, 11.8, 11.9, 13, 12.5, 14]
B = [10, 10.2, 10, 12, 14, 13]
C = [10.1, 13, 13.4, 12.9, 8.9, 10.7, 13.6, 12]

all_scores = A + B + C
company_names = (['A'] * len(A)) +  (['B'] * len(B)) +  (['C'] * len(C))

# %%
test_data = pd.DataFrame({'company':company_names, 'score':all_scores})
test_data
# Out:
#    company  score
# 0        A   12.6
# 1        A   12.0
# 2        A   11.8
# 3        A   11.9
# 4        A   13.0
# 5        A   12.5
# 6        A   14.0
# 7        B   10.0
# 8        B   10.2
# 9        B   10.0
# 10       B   12.0
# 11       B   14.0
# 12       B   13.0
# 13       C   10.1
# 14       C   13.0
# 15       C   13.4
# 16       C   12.9
# 17       C    8.9
# 18       C   10.7
# 19       C   13.6
# 20       C   12.0

# %%
test_data.groupby('company').mean()
# Out:
#              score
# company
# A        12.542857
# B        11.533333
# C        11.825000

# %%
# overall mean
overall_mean = test_data['score'].mean()
overall_mean
# Out:
# 11.980952380952381

# %% [markdown]
# $latex SStotal = \sum Y^2 – \frac{T^2}{N}&s=2$

# %%
# compute sume of squares total
test_data['overall_mean'] = overall_mean
ss_total = sum((test_data['score'] - test_data['overall_mean'])**2)
ss_total
# Out:
# 43.132380952380956

# %%
test_data.head()
# Out:
#   company  score  overall_mean
# 0       A   12.6     11.980952
# 1       A   12.0     11.980952
# 2       A   11.8     11.980952
# 3       A   11.9     11.980952
# 4       A   13.0     11.980952

# %%
# compute group means
group_means = test_data.groupby('company').mean()
group_means = group_means.rename(columns={'score':'group_mean'})
group_means
# Out:
#          group_mean  overall_mean
# company
# A         12.542857     11.980952
# B         11.533333     11.980952
# C         11.825000     11.980952

# %%
# add group means and overall means to the original DataFrame
test_data = test_data.merge(group_means, left_on='company', right_index=True)
test_data.head()
# Out:
#    company  score  overall_mean_x  group_mean  overall_mean_y
# 0        A   12.6       11.980952   12.542857       11.980952
# 1        A   12.0       11.980952   12.542857       11.980952
# 2        A   11.8       11.980952   12.542857       11.980952
# 3        A   11.9       11.980952   12.542857       11.980952
# 4        A   13.0       11.980952   12.542857       11.980952
# 5        A   12.5       11.980952   12.542857       11.980952
# 6        A   14.0       11.980952   12.542857       11.980952
# 7        B   10.0       11.980952   11.533333       11.980952
# 8        B   10.2       11.980952   11.533333       11.980952
# 9        B   10.0       11.980952   11.533333       11.980952
# 10       B   12.0       11.980952   11.533333       11.980952
# 11       B   14.0       11.980952   11.533333       11.980952
# 12       B   13.0       11.980952   11.533333       11.980952
# 13       C   10.1       11.980952   11.825000       11.980952
# 14       C   13.0       11.980952   11.825000       11.980952
# 15       C   13.4       11.980952   11.825000       11.980952
# 16       C   12.9       11.980952   11.825000       11.980952
# 17       C    8.9       11.980952   11.825000       11.980952
# 18       C   10.7       11.980952   11.825000       11.980952
# 19       C   13.6       11.980952   11.825000       11.980952
# 20       C   12.0       11.980952   11.825000       11.980952

# %%
test_data = test_data.drop(columns=['overall_mean_y'])
test_data = test_data.rename(columns={'overall_mean_x':'overall_mean'})
test_data
# Out:
#    company  score  overall_mean  group_mean
# 0        A   12.6     11.980952   12.542857
# 1        A   12.0     11.980952   12.542857
# 2        A   11.8     11.980952   12.542857
# 3        A   11.9     11.980952   12.542857
# 4        A   13.0     11.980952   12.542857
# 5        A   12.5     11.980952   12.542857
# 6        A   14.0     11.980952   12.542857
# 7        B   10.0     11.980952   11.533333
# 8        B   10.2     11.980952   11.533333
# 9        B   10.0     11.980952   11.533333
# 10       B   12.0     11.980952   11.533333
# 11       B   14.0     11.980952   11.533333
# 12       B   13.0     11.980952   11.533333
# 13       C   10.1     11.980952   11.825000
# 14       C   13.0     11.980952   11.825000
# 15       C   13.4     11.980952   11.825000
# 16       C   12.9     11.980952   11.825000
# 17       C    8.9     11.980952   11.825000
# 18       C   10.7     11.980952   11.825000
# 19       C   13.6     11.980952   11.825000
# 20       C   12.0     11.980952   11.825000

# %%
# compute sum of squares residual, aka SSError
ss_residual = sum((test_data['score'] - test_data['group_mean'])**2)
ss_residual
# Out:
# 39.52547619047619

# %%
# compute sum of squares model
ss_explained = sum((test_data['overall_mean'] - test_data['group_mean'])**2)
ss_explained
# Out:
# 3.6069047619047776

# %%
# compute Mean Square Residual (this value is the pooled SD)
n_groups = len(set(test_data['company']))
n_obs = test_data.shape[0]
df_residual = n_obs - n_groups
ms_residual = ss_residual / df_residual
ms_residual, 'pooled SD:', ms_residual **2
# Out:
# (2.1958597883597886, 'pooled SD:', 4.821800210135495)

# %%
# compute Mean Square explained
df_explained = n_groups - 1
ms_explained = ss_explained / df_explained
ms_explained
# Out:
# 1.8034523809523888

# %%
# compute F-values
f = ms_explained / ms_residual
f
# Out:
# 0.8212966923081592

# %%
# compute p-value
import scipy.stats
p_value = 1 - scipy.stats.f.cdf(f, df_explained, df_residual)
p_value
# Out:
# 0.4556832940515221

# %%
# and the easy way, using stats models
sp_stats.f_oneway(A, B, C)
# Out:
# F_onewayResult(statistic=0.8212966923081559, pvalue=0.4556832940515236)

# %%
sds = test_data.groupby('company')[['score']].std()
cnts = test_data.groupby('company')[['score']].count()

# %%
sds.columns = ['s_dev']

# %%
sds['counts'] = cnts

# %%
sds
# Out:
#             s_dev  counts
# company
# A        0.774289       7
# B        1.728198       6
# C        1.731845       8

# %%
np.sqrt(((sds['counts']-1) * sds['s_dev']**2).sum()/(sds['counts'].sum() - len(sds)))
# Out:
# 1.481843375110807

# %%
groups = [[9.7, 2.5, 50],
[12.1, 2.9, 50],
[14.5, 3.2, 50],
[17.3, 6.8, 200]]
gfd = pd.DataFrame(groups, columns=['mean', 's_dev', 'counts'])
gfd
# Out:
#    mean  s_dev  counts
# 0   9.7    2.5      50
# 1  12.1    2.9      50
# 2  14.5    3.2      50
# 3  17.3    6.8     200

# %%
np.sqrt(((gfd['counts']-1) * gfd['s_dev']**2).sum()/(gfd['counts'].sum() - len(gfd)))
# Out:
# 5.488258618082746

# %% [markdown]
# # The Pooled StDev
#
# The pooled standard deviation is an estimate of the common standard deviation for all levels. The pooled standard deviation is the standard deviation of all data points around their group mean (not around the overall mean).
# Larger groups have a proportionally greater influence on the overall estimate of the pooled standard deviation. [minitab](https://support.minitab.com/en-us/minitab/18/help-and-how-to/modeling-statistics/anova/how-to/one-way-anova/interpret-the-results/all-statistics-and-graphs/means/)
#
# Two-way ANOVA doesn't report this value - but it's easy to compute. The residual (or error) mean square reported on the ANOVA table is essentially a variance. We just need to compute its square root, which is the pooled SD.
#
# This value can also be computed from stats per group as follows [source](https://www.statisticshowto.datasciencecentral.com/pooled-standard-deviation/),
# $$ SDpooled = \sqrt{\frac{\sum_{0,k} \left( (n_i-1)*sd_i^2 \right)}{\sum_{0,k} \left( n_i \right)- k}} $$
#
# This formula computes correctly the values in these examples [1](https://support.minitab.com/en-us/minitab/18/help-and-how-to/statistics/basic-statistics/supporting-topics/data-concepts/what-is-the-pooled-standard-deviation/), [2](https://support.minitab.com/en-us/minitab/18/help-and-how-to/modeling-statistics/anova/how-to/one-way-anova/interpret-the-results/all-statistics-and-graphs/means/)
#
# If we have the value per observation and the mean per factor, the formula is, [source](https://support.minitab.com/en-us/minitab/18/help-and-how-to/statistics/basic-statistics/supporting-topics/data-concepts/what-is-the-pooled-standard-deviation/)
# $$ SDpooled = \sqrt{\frac{\sum_i \left( \left(x_i- \bar{x}_{factor} \right)^2 \right)}{N-n_{factors}}} $$
# Which produces the correct value for the second example in the source. This formula is the same used in computing the Mean Square Residual

# %%
# mean, sd, n (values per group)
groups = [[9.7, 2.5, 50],
[12.1, 2.9, 50],
[14.5, 3.2, 50],
[17.3, 6.8, 200]]

np.sqrt(np.sum([(r[2]-1) * (r[1]**2) for r in groups]) / (np.sum([r[2] for r in groups]) - len(groups)))
# Out:
# 5.488258618082746

# %%
# value, factor, mean
values = [
    [18.95, 1, 14.5033],
    [12.62, 1, 14.5033],
    [11.94, 1, 14.5033],
    [14.42, 2, 10.5567],
    [10.06, 2, 10.5567],
    [7.19, 2, 10.5567]
]

np.sqrt(np.sum([(r[0] - r[2])**2 for r in values]) / (len(values) - len(set([r[1] for r in values]))))
# Out:
# 3.7548945837400014
